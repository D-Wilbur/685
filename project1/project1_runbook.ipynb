# %%
from google.colab import drive
drive.mount('/content/drive')
import os
os.chdir('/content/drive/MyDrive/dl685_project/project/project1')  # 按你的实际路径改
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/dl685_project/project/project1
# !pwd
# !ls%cd /content/drive/MyDrive/dl685_project/project/project1
# !pwd
# !ls
# Out:
# /content
# /content/drive/MyDrive/dl685_project/project/project1
# /bin/bash: line 1: ls%cd: command not found
# /content/drive/MyDrive/dl685_project/project/project1
# data_utils.py		  README.md
# export_recon_examples.py  report_template.md
# hyperinr.py		  runs
# metrics.py		  train_downstream_classifier.py
# project1_runbook.ipynb	  train_reconstruction.py

# %% [markdown]
# # ECE 685D — Project 1 Runbook
# **Hypernetworks for Implicit Neural Representations**
#
# Run cells top-to-bottom. Each section is self-contained.
#
# | Section | Content |
# |---------|--------|
# | 0 | Setup & GPU check |
# | 1 | CIFAR-10 reconstruction — SIREN / Fourier / ReLU |
# | 2 | CIFAR-10 downstream classification — latent / theta / pixels |
# | 3 | CIFAR-10 figure export & visual comparison |
# | 4 | CelebA reconstruction — SIREN / Fourier / ReLU |
# | 5 | Super-resolution — all three architectures (64px→256px) |
# | 6 | CelebA & super-res figure export |
# | 7 | Full results summary — tables, efficiency, training curves |

# %% [markdown]
# ## Section 0 — Setup

# %%
import os
os.chdir('/home/zihan-gao/dl685/project/project1')

# %%
# !pip install lpips -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.8/53.8 kB 2.5 MB/s eta 0:00:00

# %%
import torch
print('CUDA:', torch.cuda.is_available())
print('GPU: ', torch.cuda.get_device_name(0) if torch.cuda.is_available() else 'CPU')
print('VRAM:', round(torch.cuda.get_device_properties(0).total_memory / 1e9, 1), 'GB')
# Out:
# CUDA: True
# GPU:  NVIDIA A100-SXM4-40GB
# VRAM: 42.4 GB

# %% [markdown]
# ---
# ## Section 1 — CIFAR-10 Reconstruction
#
# Train hypernetwork H(I)→θ for three coordinate-network architectures on CIFAR-10 (32×32).
# Results saved to `runs/cifar10_<arch>_recon.pt` and `runs/cifar10_<arch>_recon_metrics.jsonl`.

# %%
# SIREN — sinusoidal activations, per-layer weight scaling (~30 min)
# !python train_reconstruction.py \
  --dataset cifar10 --arch siren --image-size 32 \
  --epochs 120 --batch-size 128 --samples-per-image 4096 \
  --hidden-dim 128 --depth 4 --latent-dim 512 \
  --lr 3e-4 --weight-decay 1e-7 \
  --num-workers 8 --amp --eval-batches 50 --out-dir ./runs
# Out:
# /home/zihan-gao/miniforge3/envs/dl685/lib/python3.11/site-packages/torchvision/datasets/cifar.py:83: VisibleDeprecationWarning: dtype(): align should be passed as Python or NumPy boolean but got `align=0`. Did you mean to pass a tuple to create a subarray type? (Deprecated NumPy 2.4)
#   entry = pickle.load(f, encoding="latin1")
# Setting up [LPIPS] perceptual loss: trunk [alex], v[0.1], spatial [off]
# /home/zihan-gao/miniforge3/envs/dl685/lib/python3.11/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/zihan-gao/miniforge3/envs/dl685/lib/python3.11/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=AlexNet_Weights.IMAGENET1K_V1`. You can also use `weights=AlexNet_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Loading model from: /home/zihan-gao/miniforge3/envs/dl685/lib/python3.11/site-packages/lpips/weights/v0.1/alex.pth
# device=cuda dataset=cifar10 arch=siren total_generated_params=50307
# epoch=001 train_mse=0.035527 lr=3.00e-04 time=22.4s val_psnr=17.62 val_ssim=0.5548 val_lpips=0.2723
# saved checkpoint: runs/cifar10_siren_recon.pt
# epoch=002 train_mse=0.012773 lr=3.00e-04 time=22.4s val_psnr=18.84 val_ssim=0.6287 val_lpips=0.2683
# saved checkpoint: runs/cifar10_siren_recon.pt
# epoch=003 train_mse=0.010271 lr=3.00e-04 time=22.6s val_psnr=19.31 val_ssim=0.6610 val_lpips=0.2429
# saved checkpoint: runs/cifar10_siren_recon.pt
# epoch=004 train_mse=0.008798 lr=2.99e-04 time=22.4s val_psnr=19.41 val_ssim=0.6733 val_lpips=0.2242
# saved checkpoint: runs/cifar10_siren_recon.pt
# epoch=005 train_mse=0.008059 lr=2.99e-04 time=22.4s val_psnr=19.92 val_ssim=0.6953 val_lpips=0.2113
# saved checkpoint: runs/cifar10_siren_recon.pt
# epoch=006 train_mse=0.007345 lr=2.98e-04 time=22.3s val_psnr=20.29 val_ssim=0.7238 val_lpips=0.1869
# saved checkpoint: runs/cifar10_siren_recon.pt
# epoch=007 train_mse=0.006579 lr=2.98e-04 time=22.3s val_psnr=20.66 val_ssim=0.7386 val_lpips=0.1784
# saved checkpoint: runs/cifar10_siren_recon.pt
# epoch=008 train_mse=0.006350 lr=2.97e-04 time=22.2s val_psnr=20.95 val_ssim=0.7486 val_lpips=0.1669
# saved checkpoint: runs/cifar10_siren_recon.pt
# epoch=009 train_mse=0.005750 lr=2.96e-04 time=22.2s val_psnr=20.87 val_ssim=0.7486 val_lpips=0.1570
# epoch=010 train_mse=0.005523 lr=2.95e-04 time=22.4s val_psnr=21.45 val_ssim=0.7707 val_lpips=0.1532
# saved checkpoint: runs/cifar10_siren_recon.pt
# epoch=011 train_mse=0.005204 lr=2.94e-04 time=22.2s val_psnr=21.49 val_ssim=0.7797 val_lpips=0.1447
# saved checkpoint: runs/cifar10_siren_recon.pt
# epoch=012 train_mse=0.004948 lr=2.93e-04 time=21.9s val_psnr=21.78 val_ssim=0.7868 val_lpips=0.1430
# saved checkpoint: runs/cifar10_siren_recon.pt
# epoch=013 train_mse=0.004680 lr=2.91e-04 time=22.0s val_psnr=21.84 val_ssim=0.7916 val_lpips=0.1397
# saved checkpoint: runs/cifar10_siren_recon.pt
# epoch=014 train_mse=0.004507 lr=2.90e-04 time=21.8s val_psnr=22.13 val_ssim=0.8067 val_lpips=0.1316
# saved checkpoint: runs/cifar10_siren_recon.pt
# epoch=015 train_mse=0.004393 lr=2.89e-04 time=22.1s val_psnr=22.16 val_ssim=0.8008 val_lpips=0.1320
# saved checkpoint: runs/cifar10_siren_recon.pt
# epoch=016 train_mse=0.004212 lr=2.87e-04 time=21.9s val_psnr=22.31 val_ssim=0.8097 val_lpips=0.1261
# saved checkpoint: runs/cifar10_siren_recon.pt
# epoch=017 train_mse=0.004067 lr=2.86e-04 time=22.0s val_psnr=22.36 val_ssim=0.8139 val_lpips=0.1231
# saved checkpoint: runs/cifar10_siren_recon.pt
# epoch=018 train_mse=0.003984 lr=2.84e-04 time=21.7s val_psnr=22.37 val_ssim=0.8148 val_lpips=0.1212
# saved checkpoint: runs/cifar10_siren_recon.pt
# epoch=019 train_mse=0.003822 lr=2.82e-04 time=21.3s val_psnr=22.67 val_ssim=0.8232 val_lpips=0.1163
# saved checkpoint: runs/cifar10_siren_recon.pt
# epoch=020 train_mse=0.003650 lr=2.80e-04 time=21.2s val_psnr=22.54 val_ssim=0.8244 val_lpips=0.1132
# epoch=021 train_mse=0.003604 lr=2.78e-04 time=21.5s val_psnr=22.76 val_ssim=0.8295 val_lpips=0.1124
# saved checkpoint: runs/cifar10_siren_recon.pt
# epoch=022 train_mse=0.003472 lr=2.76e-04 time=21.6s val_psnr=22.87 val_ssim=0.8301 val_lpips=0.1088
# saved checkpoint: runs/cifar10_siren_recon.pt
# epoch=023 train_mse=0.003259 lr=2.74e-04 time=21.3s val_psnr=22.95 val_ssim=0.8375 val_lpips=0.1058
# saved checkpoint: runs/cifar10_siren_recon.pt
# epoch=024 train_mse=0.003197 lr=2.72e-04 time=21.0s val_psnr=22.90 val_ssim=0.8374 val_lpips=0.1024
# epoch=025 train_mse=0.003128 lr=2.69e-04 time=21.0s val_psnr=23.38 val_ssim=0.8507 val_lpips=0.0963
# saved checkpoint: runs/cifar10_siren_recon.pt
# epoch=026 train_mse=0.003052 lr=2.67e-04 time=21.0s val_psnr=23.55 val_ssim=0.8516 val_lpips=0.0937
# saved checkpoint: runs/cifar10_siren_recon.pt
# epoch=027 train_mse=0.002963 lr=2.64e-04 time=20.9s val_psnr=23.46 val_ssim=0.8517 val_lpips=0.0929
# epoch=028 train_mse=0.002905 lr=2.62e-04 time=20.9s val_psnr=23.49 val_ssim=0.8528 val_lpips=0.0911
# epoch=029 train_mse=0.002860 lr=2.59e-04 time=21.2s val_psnr=23.60 val_ssim=0.8555 val_lpips=0.0903
# saved checkpoint: runs/cifar10_siren_recon.pt
# epoch=030 train_mse=0.002738 lr=2.57e-04 time=21.3s val_psnr=23.68 val_ssim=0.8574 val_lpips=0.0846
# saved checkpoint: runs/cifar10_siren_recon.pt
# epoch=031 train_mse=0.002742 lr=2.54e-04 time=21.4s val_psnr=23.83 val_ssim=0.8603 val_lpips=0.0855
# saved checkpoint: runs/cifar10_siren_recon.pt
# epoch=032 train_mse=0.002615 lr=2.51e-04 time=22.0s val_psnr=23.95 val_ssim=0.8636 val_lpips=0.0841
# saved checkpoint: runs/cifar10_siren_recon.pt
# epoch=033 train_mse=0.002531 lr=2.48e-04 time=22.5s val_psnr=23.99 val_ssim=0.8658 val_lpips=0.0807
# saved checkpoint: runs/cifar10_siren_recon.pt
# epoch=034 train_mse=0.002544 lr=2.45e-04 time=22.5s val_psnr=23.98 val_ssim=0.8684 val_lpips=0.0798
# epoch=035 train_mse=0.002452 lr=2.42e-04 time=22.6s val_psnr=24.20 val_ssim=0.8728 val_lpips=0.0759
# saved checkpoint: runs/cifar10_siren_recon.pt
# epoch=036 train_mse=0.002422 lr=2.39e-04 time=22.4s val_psnr=24.24 val_ssim=0.8742 val_lpips=0.0754
# saved checkpoint: runs/cifar10_siren_recon.pt
# epoch=037 train_mse=0.002329 lr=2.36e-04 time=22.3s val_psnr=24.41 val_ssim=0.8777 val_lpips=0.0742
# saved checkpoint: runs/cifar10_siren_recon.pt
# epoch=038 train_mse=0.002354 lr=2.32e-04 time=22.2s val_psnr=24.36 val_ssim=0.8761 val_lpips=0.0737
# epoch=039 train_mse=0.002292 lr=2.29e-04 time=22.2s val_psnr=24.32 val_ssim=0.8757 val_lpips=0.0729
# epoch=040 train_mse=0.002276 lr=2.26e-04 time=22.3s val_psnr=24.30 val_ssim=0.8768 val_lpips=0.0700
# epoch=041 train_mse=0.002212 lr=2.22e-04 time=22.3s val_psnr=24.43 val_ssim=0.8765 val_lpips=0.0701
# saved checkpoint: runs/cifar10_siren_recon.pt
# epoch=042 train_mse=0.002170 lr=2.19e-04 time=22.3s val_psnr=24.53 val_ssim=0.8798 val_lpips=0.0679
# saved checkpoint: runs/cifar10_siren_recon.pt
# epoch=043 train_mse=0.002173 lr=2.15e-04 time=22.3s val_psnr=24.47 val_ssim=0.8805 val_lpips=0.0667
# epoch=044 train_mse=0.002092 lr=2.12e-04 time=22.3s val_psnr=24.69 val_ssim=0.8845 val_lpips=0.0651
# saved checkpoint: runs/cifar10_siren_recon.pt
# epoch=045 train_mse=0.002066 lr=2.08e-04 time=22.3s val_psnr=24.54 val_ssim=0.8814 val_lpips=0.0652
# epoch=046 train_mse=0.002057 lr=2.05e-04 time=22.3s val_psnr=24.67 val_ssim=0.8839 val_lpips=0.0633
# epoch=047 train_mse=0.001999 lr=2.01e-04 time=22.2s val_psnr=24.83 val_ssim=0.8883 val_lpips=0.0629
# saved checkpoint: runs/cifar10_siren_recon.pt
# epoch=048 train_mse=0.001975 lr=1.97e-04 time=22.2s val_psnr=24.77 val_ssim=0.8872 val_lpips=0.0616
# epoch=049 train_mse=0.001950 lr=1.94e-04 time=22.2s val_psnr=24.84 val_ssim=0.8886 val_lpips=0.0614
# saved checkpoint: runs/cifar10_siren_recon.pt
# epoch=050 train_mse=0.001938 lr=1.90e-04 time=22.1s val_psnr=24.77 val_ssim=0.8868 val_lpips=0.0611
# epoch=051 train_mse=0.001914 lr=1.86e-04 time=22.2s val_psnr=24.72 val_ssim=0.8849 val_lpips=0.0616
# epoch=052 train_mse=0.001895 lr=1.82e-04 time=22.1s val_psnr=24.80 val_ssim=0.8894 val_lpips=0.0588
# epoch=053 train_mse=0.001863 lr=1.79e-04 time=22.1s val_psnr=25.12 val_ssim=0.8934 val_lpips=0.0557
# saved checkpoint: runs/cifar10_siren_recon.pt
# epoch=054 train_mse=0.001849 lr=1.75e-04 time=22.1s val_psnr=25.14 val_ssim=0.8944 val_lpips=0.0566
# saved checkpoint: runs/cifar10_siren_recon.pt
# epoch=055 train_mse=0.001855 lr=1.71e-04 time=22.0s val_psnr=24.99 val_ssim=0.8928 val_lpips=0.0555
# epoch=056 train_mse=0.001811 lr=1.67e-04 time=22.1s val_psnr=25.13 val_ssim=0.8948 val_lpips=0.0540
# epoch=057 train_mse=0.001781 lr=1.63e-04 time=22.2s val_psnr=25.31 val_ssim=0.8986 val_lpips=0.0531
# saved checkpoint: runs/cifar10_siren_recon.pt
# epoch=058 train_mse=0.001756 lr=1.59e-04 time=22.4s val_psnr=25.18 val_ssim=0.8971 val_lpips=0.0542
# epoch=059 train_mse=0.001733 lr=1.55e-04 time=22.5s val_psnr=25.34 val_ssim=0.8992 val_lpips=0.0523
# saved checkpoint: runs/cifar10_siren_recon.pt
# epoch=060 train_mse=0.001744 lr=1.51e-04 time=22.5s val_psnr=25.22 val_ssim=0.8982 val_lpips=0.0520
# epoch=061 train_mse=0.001720 lr=1.48e-04 time=22.5s val_psnr=25.14 val_ssim=0.8958 val_lpips=0.0520
# epoch=062 train_mse=0.001694 lr=1.44e-04 time=22.5s val_psnr=25.37 val_ssim=0.8998 val_lpips=0.0512
# saved checkpoint: runs/cifar10_siren_recon.pt
# epoch=063 train_mse=0.001685 lr=1.40e-04 time=22.5s val_psnr=25.32 val_ssim=0.8998 val_lpips=0.0507
# epoch=064 train_mse=0.001624 lr=1.36e-04 time=22.5s val_psnr=25.46 val_ssim=0.9028 val_lpips=0.0491
# saved checkpoint: runs/cifar10_siren_recon.pt
# epoch=065 train_mse=0.001632 lr=1.32e-04 time=22.5s val_psnr=25.54 val_ssim=0.9034 val_lpips=0.0488
# saved checkpoint: runs/cifar10_siren_recon.pt
# epoch=066 train_mse=0.001618 lr=1.28e-04 time=22.5s val_psnr=25.35 val_ssim=0.9021 val_lpips=0.0482
# epoch=067 train_mse=0.001596 lr=1.24e-04 time=22.5s val_psnr=25.63 val_ssim=0.9048 val_lpips=0.0475
# saved checkpoint: runs/cifar10_siren_recon.pt
# epoch=068 train_mse=0.001589 lr=1.21e-04 time=22.6s val_psnr=25.58 val_ssim=0.9034 val_lpips=0.0468
# epoch=069 train_mse=0.001607 lr=1.17e-04 time=22.5s val_psnr=25.39 val_ssim=0.9015 val_lpips=0.0472
# epoch=070 train_mse=0.001581 lr=1.13e-04 time=22.5s val_psnr=25.58 val_ssim=0.9034 val_lpips=0.0466
# epoch=071 train_mse=0.001533 lr=1.09e-04 time=22.5s val_psnr=25.64 val_ssim=0.9068 val_lpips=0.0447
# saved checkpoint: runs/cifar10_siren_recon.pt
# epoch=072 train_mse=0.001543 lr=1.06e-04 time=22.5s val_psnr=25.45 val_ssim=0.9029 val_lpips=0.0460
# epoch=073 train_mse=0.001521 lr=1.02e-04 time=22.5s val_psnr=25.71 val_ssim=0.9081 val_lpips=0.0444
# saved checkpoint: runs/cifar10_siren_recon.pt
# epoch=074 train_mse=0.001518 lr=9.83e-05 time=22.4s val_psnr=25.72 val_ssim=0.9065 val_lpips=0.0448
# saved checkpoint: runs/cifar10_siren_recon.pt
# epoch=075 train_mse=0.001488 lr=9.47e-05 time=22.4s val_psnr=25.75 val_ssim=0.9068 val_lpips=0.0446
# saved checkpoint: runs/cifar10_siren_recon.pt
# epoch=076 train_mse=0.001463 lr=9.11e-05 time=22.5s val_psnr=25.73 val_ssim=0.9076 val_lpips=0.0442
# epoch=077 train_mse=0.001491 lr=8.76e-05 time=22.4s val_psnr=25.89 val_ssim=0.9098 val_lpips=0.0429
# saved checkpoint: runs/cifar10_siren_recon.pt
# epoch=078 train_mse=0.001451 lr=8.41e-05 time=22.4s val_psnr=25.90 val_ssim=0.9099 val_lpips=0.0430
# saved checkpoint: runs/cifar10_siren_recon.pt
# epoch=079 train_mse=0.001437 lr=8.06e-05 time=22.4s val_psnr=25.90 val_ssim=0.9098 val_lpips=0.0422
# saved checkpoint: runs/cifar10_siren_recon.pt
# epoch=080 train_mse=0.001440 lr=7.73e-05 time=22.2s val_psnr=25.81 val_ssim=0.9089 val_lpips=0.0433
# epoch=081 train_mse=0.001412 lr=7.39e-05 time=22.3s val_psnr=25.83 val_ssim=0.9095 val_lpips=0.0420
# epoch=082 train_mse=0.001416 lr=7.06e-05 time=22.3s val_psnr=25.86 val_ssim=0.9103 val_lpips=0.0414
# epoch=083 train_mse=0.001402 lr=6.74e-05 time=22.2s val_psnr=25.88 val_ssim=0.9094 val_lpips=0.0415
# epoch=084 train_mse=0.001416 lr=6.42e-05 time=22.3s val_psnr=25.89 val_ssim=0.9104 val_lpips=0.0415
# epoch=085 train_mse=0.001363 lr=6.11e-05 time=22.3s val_psnr=26.07 val_ssim=0.9128 val_lpips=0.0401
# saved checkpoint: runs/cifar10_siren_recon.pt
# epoch=086 train_mse=0.001362 lr=5.80e-05 time=22.2s val_psnr=26.12 val_ssim=0.9143 val_lpips=0.0397
# saved checkpoint: runs/cifar10_siren_recon.pt
# epoch=087 train_mse=0.001364 lr=5.51e-05 time=22.2s val_psnr=25.97 val_ssim=0.9118 val_lpips=0.0398
# epoch=088 train_mse=0.001349 lr=5.21e-05 time=22.3s val_psnr=26.08 val_ssim=0.9141 val_lpips=0.0390
# epoch=089 train_mse=0.001327 lr=4.93e-05 time=22.3s val_psnr=26.09 val_ssim=0.9136 val_lpips=0.0391
# epoch=090 train_mse=0.001329 lr=4.65e-05 time=22.2s val_psnr=26.16 val_ssim=0.9147 val_lpips=0.0388
# saved checkpoint: runs/cifar10_siren_recon.pt
# epoch=091 train_mse=0.001329 lr=4.38e-05 time=22.2s val_psnr=26.09 val_ssim=0.9139 val_lpips=0.0389
# epoch=092 train_mse=0.001306 lr=4.11e-05 time=22.2s val_psnr=26.07 val_ssim=0.9139 val_lpips=0.0386
# epoch=093 train_mse=0.001300 lr=3.86e-05 time=22.1s val_psnr=26.20 val_ssim=0.9158 val_lpips=0.0381
# saved checkpoint: runs/cifar10_siren_recon.pt
# epoch=094 train_mse=0.001301 lr=3.61e-05 time=22.1s val_psnr=26.18 val_ssim=0.9148 val_lpips=0.0382
# epoch=095 train_mse=0.001302 lr=3.37e-05 time=22.1s val_psnr=26.15 val_ssim=0.9146 val_lpips=0.0382
# epoch=096 train_mse=0.001275 lr=3.14e-05 time=22.2s val_psnr=26.27 val_ssim=0.9165 val_lpips=0.0373
# saved checkpoint: runs/cifar10_siren_recon.pt
# epoch=097 train_mse=0.001277 lr=2.91e-05 time=22.3s val_psnr=26.14 val_ssim=0.9146 val_lpips=0.0375
# epoch=098 train_mse=0.001269 lr=2.70e-05 time=22.4s val_psnr=26.22 val_ssim=0.9158 val_lpips=0.0371
# epoch=099 train_mse=0.001267 lr=2.49e-05 time=22.5s val_psnr=26.31 val_ssim=0.9175 val_lpips=0.0366
# saved checkpoint: runs/cifar10_siren_recon.pt
# epoch=100 train_mse=0.001252 lr=2.29e-05 time=22.3s val_psnr=26.31 val_ssim=0.9171 val_lpips=0.0368
# epoch=101 train_mse=0.001245 lr=2.10e-05 time=22.4s val_psnr=26.28 val_ssim=0.9171 val_lpips=0.0367
# epoch=102 train_mse=0.001237 lr=1.92e-05 time=22.5s val_psnr=26.34 val_ssim=0.9177 val_lpips=0.0363
# saved checkpoint: runs/cifar10_siren_recon.pt
# epoch=103 train_mse=0.001237 lr=1.75e-05 time=22.3s val_psnr=26.31 val_ssim=0.9176 val_lpips=0.0361
# epoch=104 train_mse=0.001230 lr=1.58e-05 time=22.3s val_psnr=26.36 val_ssim=0.9182 val_lpips=0.0360
# saved checkpoint: runs/cifar10_siren_recon.pt
# epoch=105 train_mse=0.001226 lr=1.43e-05 time=22.2s val_psnr=26.39 val_ssim=0.9187 val_lpips=0.0359
# saved checkpoint: runs/cifar10_siren_recon.pt
# epoch=106 train_mse=0.001228 lr=1.29e-05 time=22.2s val_psnr=26.31 val_ssim=0.9179 val_lpips=0.0358
# epoch=107 train_mse=0.001215 lr=1.15e-05 time=22.2s val_psnr=26.32 val_ssim=0.9182 val_lpips=0.0354
# epoch=108 train_mse=0.001212 lr=1.03e-05 time=22.2s val_psnr=26.42 val_ssim=0.9192 val_lpips=0.0355
# saved checkpoint: runs/cifar10_siren_recon.pt
# epoch=109 train_mse=0.001205 lr=9.12e-06 time=22.2s val_psnr=26.41 val_ssim=0.9190 val_lpips=0.0353
# epoch=110 train_mse=0.001205 lr=8.06e-06 time=22.2s val_psnr=26.44 val_ssim=0.9194 val_lpips=0.0352
# saved checkpoint: runs/cifar10_siren_recon.pt
# epoch=111 train_mse=0.001200 lr=7.10e-06 time=22.2s val_psnr=26.43 val_ssim=0.9192 val_lpips=0.0352
# epoch=112 train_mse=0.001200 lr=6.25e-06 time=22.2s val_psnr=26.47 val_ssim=0.9199 val_lpips=0.0349
# saved checkpoint: runs/cifar10_siren_recon.pt
# epoch=113 train_mse=0.001194 lr=5.49e-06 time=22.3s val_psnr=26.41 val_ssim=0.9191 val_lpips=0.0352
# epoch=114 train_mse=0.001191 lr=4.83e-06 time=22.3s val_psnr=26.46 val_ssim=0.9197 val_lpips=0.0349
# epoch=115 train_mse=0.001184 lr=4.27e-06 time=22.2s val_psnr=26.43 val_ssim=0.9193 val_lpips=0.0351
# epoch=116 train_mse=0.001189 lr=3.81e-06 time=22.4s val_psnr=26.48 val_ssim=0.9202 val_lpips=0.0345
# saved checkpoint: runs/cifar10_siren_recon.pt
# epoch=117 train_mse=0.001184 lr=3.46e-06 time=22.4s val_psnr=26.48 val_ssim=0.9201 val_lpips=0.0343
# epoch=118 train_mse=0.001182 lr=3.20e-06 time=22.6s val_psnr=26.47 val_ssim=0.9199 val_lpips=0.0345
# epoch=119 train_mse=0.001183 lr=3.05e-06 time=22.3s val_psnr=26.47 val_ssim=0.9199 val_lpips=0.0350
# epoch=120 train_mse=0.001180 lr=3.00e-06 time=22.3s val_psnr=26.46 val_ssim=0.9197 val_lpips=0.0347

# %%
# Fourier — random Gaussian frequency features (~30 min)
# !python train_reconstruction.py \
  --dataset cifar10 --arch fourier --image-size 32 \
  --epochs 120 --batch-size 128 --samples-per-image 4096 \
  --hidden-dim 128 --depth 4 --latent-dim 512 \
  --fourier-features 32 --fourier-sigma 10 \
  --lr 3e-4 --weight-decay 1e-7 \
  --num-workers 8 --amp --eval-batches 50 --out-dir ./runs
# Out:
# /home/zihan-gao/miniforge3/envs/dl685/lib/python3.11/site-packages/torchvision/datasets/cifar.py:83: VisibleDeprecationWarning: dtype(): align should be passed as Python or NumPy boolean but got `align=0`. Did you mean to pass a tuple to create a subarray type? (Deprecated NumPy 2.4)
#   entry = pickle.load(f, encoding="latin1")
# Setting up [LPIPS] perceptual loss: trunk [alex], v[0.1], spatial [off]
# /home/zihan-gao/miniforge3/envs/dl685/lib/python3.11/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/zihan-gao/miniforge3/envs/dl685/lib/python3.11/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=AlexNet_Weights.IMAGENET1K_V1`. You can also use `weights=AlexNet_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Loading model from: /home/zihan-gao/miniforge3/envs/dl685/lib/python3.11/site-packages/lpips/weights/v0.1/alex.pth
# device=cuda dataset=cifar10 arch=fourier total_generated_params=58243
# epoch=001 train_mse=0.038643 lr=3.00e-04 time=19.5s val_psnr=16.39 val_ssim=0.4707 val_lpips=0.1966
# saved checkpoint: runs/cifar10_fourier_recon.pt
# epoch=002 train_mse=0.015177 lr=3.00e-04 time=18.9s val_psnr=18.40 val_ssim=0.6009 val_lpips=0.1337
# saved checkpoint: runs/cifar10_fourier_recon.pt
# epoch=003 train_mse=0.010377 lr=3.00e-04 time=18.9s val_psnr=19.51 val_ssim=0.6693 val_lpips=0.1257
# saved checkpoint: runs/cifar10_fourier_recon.pt
# epoch=004 train_mse=0.008621 lr=2.99e-04 time=19.0s val_psnr=19.86 val_ssim=0.6978 val_lpips=0.1224
# saved checkpoint: runs/cifar10_fourier_recon.pt
# epoch=005 train_mse=0.007314 lr=2.99e-04 time=19.0s val_psnr=20.49 val_ssim=0.7320 val_lpips=0.1159
# saved checkpoint: runs/cifar10_fourier_recon.pt
# epoch=006 train_mse=0.006635 lr=2.98e-04 time=19.1s val_psnr=20.81 val_ssim=0.7460 val_lpips=0.1146
# saved checkpoint: runs/cifar10_fourier_recon.pt
# epoch=007 train_mse=0.006088 lr=2.98e-04 time=18.9s val_psnr=21.34 val_ssim=0.7667 val_lpips=0.1085
# saved checkpoint: runs/cifar10_fourier_recon.pt
# epoch=008 train_mse=0.005530 lr=2.97e-04 time=18.9s val_psnr=20.78 val_ssim=0.7663 val_lpips=0.1066
# epoch=009 train_mse=0.005247 lr=2.96e-04 time=19.1s val_psnr=21.78 val_ssim=0.7893 val_lpips=0.1017
# saved checkpoint: runs/cifar10_fourier_recon.pt
# epoch=010 train_mse=0.004963 lr=2.95e-04 time=19.0s val_psnr=21.98 val_ssim=0.7975 val_lpips=0.0990
# saved checkpoint: runs/cifar10_fourier_recon.pt
# epoch=011 train_mse=0.004629 lr=2.94e-04 time=19.1s val_psnr=22.08 val_ssim=0.8022 val_lpips=0.0979
# saved checkpoint: runs/cifar10_fourier_recon.pt
# epoch=012 train_mse=0.004387 lr=2.93e-04 time=19.2s val_psnr=22.16 val_ssim=0.8099 val_lpips=0.0952
# saved checkpoint: runs/cifar10_fourier_recon.pt
# epoch=013 train_mse=0.004175 lr=2.91e-04 time=19.1s val_psnr=22.45 val_ssim=0.8199 val_lpips=0.0905
# saved checkpoint: runs/cifar10_fourier_recon.pt
# epoch=014 train_mse=0.003997 lr=2.90e-04 time=19.0s val_psnr=22.69 val_ssim=0.8271 val_lpips=0.0894
# saved checkpoint: runs/cifar10_fourier_recon.pt
# epoch=015 train_mse=0.003940 lr=2.89e-04 time=19.0s val_psnr=22.67 val_ssim=0.8262 val_lpips=0.0891
# epoch=016 train_mse=0.003755 lr=2.87e-04 time=19.1s val_psnr=22.46 val_ssim=0.8268 val_lpips=0.0894
# epoch=017 train_mse=0.003724 lr=2.86e-04 time=19.1s val_psnr=21.94 val_ssim=0.8221 val_lpips=0.0890
# epoch=018 train_mse=0.003532 lr=2.84e-04 time=19.1s val_psnr=22.87 val_ssim=0.8379 val_lpips=0.0826
# saved checkpoint: runs/cifar10_fourier_recon.pt
# epoch=019 train_mse=0.003423 lr=2.82e-04 time=19.2s val_psnr=23.18 val_ssim=0.8443 val_lpips=0.0820
# saved checkpoint: runs/cifar10_fourier_recon.pt
# epoch=020 train_mse=0.003308 lr=2.80e-04 time=19.1s val_psnr=23.08 val_ssim=0.8448 val_lpips=0.0847
# epoch=021 train_mse=0.003235 lr=2.78e-04 time=19.0s val_psnr=23.48 val_ssim=0.8529 val_lpips=0.0787
# saved checkpoint: runs/cifar10_fourier_recon.pt
# epoch=022 train_mse=0.003262 lr=2.76e-04 time=19.0s val_psnr=23.62 val_ssim=0.8553 val_lpips=0.0775
# saved checkpoint: runs/cifar10_fourier_recon.pt
# epoch=023 train_mse=0.002937 lr=2.74e-04 time=19.0s val_psnr=23.47 val_ssim=0.8528 val_lpips=0.0774
# epoch=024 train_mse=0.003091 lr=2.72e-04 time=19.1s val_psnr=23.62 val_ssim=0.8594 val_lpips=0.0741
# epoch=025 train_mse=0.002988 lr=2.69e-04 time=19.0s val_psnr=23.39 val_ssim=0.8586 val_lpips=0.0748
# epoch=026 train_mse=0.002893 lr=2.67e-04 time=19.0s val_psnr=23.72 val_ssim=0.8588 val_lpips=0.0752
# saved checkpoint: runs/cifar10_fourier_recon.pt
# epoch=027 train_mse=0.002751 lr=2.64e-04 time=19.1s val_psnr=23.58 val_ssim=0.8669 val_lpips=0.0688
# epoch=028 train_mse=0.002654 lr=2.62e-04 time=19.2s val_psnr=23.50 val_ssim=0.8616 val_lpips=0.0714
# epoch=029 train_mse=0.002630 lr=2.59e-04 time=19.0s val_psnr=24.04 val_ssim=0.8711 val_lpips=0.0672
# saved checkpoint: runs/cifar10_fourier_recon.pt
# epoch=030 train_mse=0.002566 lr=2.57e-04 time=18.9s val_psnr=24.20 val_ssim=0.8735 val_lpips=0.0650
# saved checkpoint: runs/cifar10_fourier_recon.pt
# epoch=031 train_mse=0.002533 lr=2.54e-04 time=18.9s val_psnr=24.28 val_ssim=0.8750 val_lpips=0.0644
# saved checkpoint: runs/cifar10_fourier_recon.pt
# epoch=032 train_mse=0.002514 lr=2.51e-04 time=18.9s val_psnr=24.10 val_ssim=0.8725 val_lpips=0.0653
# epoch=033 train_mse=0.002515 lr=2.48e-04 time=19.0s val_psnr=24.13 val_ssim=0.8723 val_lpips=0.0645
# epoch=034 train_mse=0.002444 lr=2.45e-04 time=18.9s val_psnr=24.31 val_ssim=0.8776 val_lpips=0.0618
# saved checkpoint: runs/cifar10_fourier_recon.pt
# epoch=035 train_mse=0.002309 lr=2.42e-04 time=18.9s val_psnr=24.21 val_ssim=0.8765 val_lpips=0.0608
# epoch=036 train_mse=0.002303 lr=2.39e-04 time=18.8s val_psnr=24.62 val_ssim=0.8833 val_lpips=0.0583
# saved checkpoint: runs/cifar10_fourier_recon.pt
# epoch=037 train_mse=0.002313 lr=2.36e-04 time=18.9s val_psnr=24.55 val_ssim=0.8819 val_lpips=0.0592
# epoch=038 train_mse=0.002256 lr=2.32e-04 time=18.8s val_psnr=24.30 val_ssim=0.8783 val_lpips=0.0605
# epoch=039 train_mse=0.002308 lr=2.29e-04 time=18.9s val_psnr=24.24 val_ssim=0.8787 val_lpips=0.0600
# epoch=040 train_mse=0.002244 lr=2.26e-04 time=19.1s val_psnr=24.57 val_ssim=0.8845 val_lpips=0.0562
# epoch=041 train_mse=0.002088 lr=2.22e-04 time=19.1s val_psnr=24.68 val_ssim=0.8870 val_lpips=0.0551
# saved checkpoint: runs/cifar10_fourier_recon.pt
# epoch=042 train_mse=0.002147 lr=2.19e-04 time=19.0s val_psnr=24.72 val_ssim=0.8869 val_lpips=0.0546
# saved checkpoint: runs/cifar10_fourier_recon.pt
# epoch=043 train_mse=0.002070 lr=2.15e-04 time=19.0s val_psnr=24.81 val_ssim=0.8891 val_lpips=0.0539
# saved checkpoint: runs/cifar10_fourier_recon.pt
# epoch=044 train_mse=0.002049 lr=2.12e-04 time=19.0s val_psnr=24.89 val_ssim=0.8920 val_lpips=0.0523
# saved checkpoint: runs/cifar10_fourier_recon.pt
# epoch=045 train_mse=0.002005 lr=2.08e-04 time=19.0s val_psnr=24.81 val_ssim=0.8911 val_lpips=0.0520
# epoch=046 train_mse=0.002021 lr=2.05e-04 time=19.1s val_psnr=24.88 val_ssim=0.8918 val_lpips=0.0508
# epoch=047 train_mse=0.001974 lr=2.01e-04 time=18.9s val_psnr=25.05 val_ssim=0.8940 val_lpips=0.0499
# saved checkpoint: runs/cifar10_fourier_recon.pt
# epoch=048 train_mse=0.001954 lr=1.97e-04 time=18.8s val_psnr=24.59 val_ssim=0.8914 val_lpips=0.0500
# epoch=049 train_mse=0.001960 lr=1.94e-04 time=18.7s val_psnr=24.86 val_ssim=0.8918 val_lpips=0.0493
# epoch=050 train_mse=0.001911 lr=1.90e-04 time=18.6s val_psnr=24.97 val_ssim=0.8939 val_lpips=0.0485
# epoch=051 train_mse=0.001874 lr=1.86e-04 time=18.6s val_psnr=25.03 val_ssim=0.8965 val_lpips=0.0466
# epoch=052 train_mse=0.001854 lr=1.82e-04 time=18.7s val_psnr=25.32 val_ssim=0.8986 val_lpips=0.0454
# saved checkpoint: runs/cifar10_fourier_recon.pt
# epoch=053 train_mse=0.001829 lr=1.79e-04 time=18.6s val_psnr=25.26 val_ssim=0.8981 val_lpips=0.0470
# epoch=054 train_mse=0.001831 lr=1.75e-04 time=18.6s val_psnr=24.98 val_ssim=0.8971 val_lpips=0.0466
# epoch=055 train_mse=0.001757 lr=1.71e-04 time=18.6s val_psnr=25.20 val_ssim=0.8989 val_lpips=0.0451
# epoch=056 train_mse=0.001760 lr=1.67e-04 time=18.6s val_psnr=25.10 val_ssim=0.8994 val_lpips=0.0439
# epoch=057 train_mse=0.001755 lr=1.63e-04 time=18.6s val_psnr=25.50 val_ssim=0.9027 val_lpips=0.0424
# saved checkpoint: runs/cifar10_fourier_recon.pt
# epoch=058 train_mse=0.001724 lr=1.59e-04 time=18.6s val_psnr=25.42 val_ssim=0.9015 val_lpips=0.0427
# epoch=059 train_mse=0.001707 lr=1.55e-04 time=18.6s val_psnr=25.43 val_ssim=0.9026 val_lpips=0.0421
# epoch=060 train_mse=0.001729 lr=1.51e-04 time=18.6s val_psnr=25.47 val_ssim=0.9021 val_lpips=0.0413
# epoch=061 train_mse=0.001695 lr=1.48e-04 time=18.6s val_psnr=25.27 val_ssim=0.9034 val_lpips=0.0410
# epoch=062 train_mse=0.001635 lr=1.44e-04 time=18.6s val_psnr=25.41 val_ssim=0.9042 val_lpips=0.0408
# epoch=063 train_mse=0.001635 lr=1.40e-04 time=18.6s val_psnr=25.41 val_ssim=0.9043 val_lpips=0.0400
# epoch=064 train_mse=0.001600 lr=1.36e-04 time=18.6s val_psnr=25.47 val_ssim=0.9049 val_lpips=0.0394
# epoch=065 train_mse=0.001619 lr=1.32e-04 time=18.6s val_psnr=25.57 val_ssim=0.9050 val_lpips=0.0391
# saved checkpoint: runs/cifar10_fourier_recon.pt
# epoch=066 train_mse=0.001585 lr=1.28e-04 time=18.5s val_psnr=25.68 val_ssim=0.9067 val_lpips=0.0386
# saved checkpoint: runs/cifar10_fourier_recon.pt
# epoch=067 train_mse=0.001577 lr=1.24e-04 time=18.5s val_psnr=25.36 val_ssim=0.9053 val_lpips=0.0395
# epoch=068 train_mse=0.001581 lr=1.21e-04 time=18.6s val_psnr=25.68 val_ssim=0.9072 val_lpips=0.0371
# saved checkpoint: runs/cifar10_fourier_recon.pt
# epoch=069 train_mse=0.001569 lr=1.17e-04 time=18.6s val_psnr=25.83 val_ssim=0.9093 val_lpips=0.0361
# saved checkpoint: runs/cifar10_fourier_recon.pt
# epoch=070 train_mse=0.001543 lr=1.13e-04 time=18.6s val_psnr=25.61 val_ssim=0.9079 val_lpips=0.0377
# epoch=071 train_mse=0.001507 lr=1.09e-04 time=18.5s val_psnr=25.57 val_ssim=0.9086 val_lpips=0.0363
# epoch=072 train_mse=0.001511 lr=1.06e-04 time=18.7s val_psnr=25.77 val_ssim=0.9092 val_lpips=0.0359
# epoch=073 train_mse=0.001486 lr=1.02e-04 time=18.9s val_psnr=25.69 val_ssim=0.9100 val_lpips=0.0354
# epoch=074 train_mse=0.001489 lr=9.83e-05 time=19.0s val_psnr=25.86 val_ssim=0.9106 val_lpips=0.0346
# saved checkpoint: runs/cifar10_fourier_recon.pt
# epoch=075 train_mse=0.001447 lr=9.47e-05 time=19.0s val_psnr=25.96 val_ssim=0.9115 val_lpips=0.0342
# saved checkpoint: runs/cifar10_fourier_recon.pt
# epoch=076 train_mse=0.001448 lr=9.11e-05 time=19.1s val_psnr=25.80 val_ssim=0.9107 val_lpips=0.0349
# epoch=077 train_mse=0.001436 lr=8.76e-05 time=19.1s val_psnr=26.02 val_ssim=0.9131 val_lpips=0.0338
# saved checkpoint: runs/cifar10_fourier_recon.pt
# epoch=078 train_mse=0.001422 lr=8.41e-05 time=19.0s val_psnr=26.02 val_ssim=0.9130 val_lpips=0.0329
# saved checkpoint: runs/cifar10_fourier_recon.pt
# epoch=079 train_mse=0.001409 lr=8.06e-05 time=19.1s val_psnr=25.83 val_ssim=0.9130 val_lpips=0.0329
# epoch=080 train_mse=0.001392 lr=7.73e-05 time=18.9s val_psnr=25.99 val_ssim=0.9134 val_lpips=0.0324
# epoch=081 train_mse=0.001421 lr=7.39e-05 time=19.0s val_psnr=25.99 val_ssim=0.9136 val_lpips=0.0329
# epoch=082 train_mse=0.001382 lr=7.06e-05 time=18.9s val_psnr=26.08 val_ssim=0.9144 val_lpips=0.0326
# saved checkpoint: runs/cifar10_fourier_recon.pt
# epoch=083 train_mse=0.001377 lr=6.74e-05 time=19.0s val_psnr=25.89 val_ssim=0.9132 val_lpips=0.0322
# epoch=084 train_mse=0.001372 lr=6.42e-05 time=18.9s val_psnr=26.15 val_ssim=0.9151 val_lpips=0.0313
# saved checkpoint: runs/cifar10_fourier_recon.pt
# epoch=085 train_mse=0.001353 lr=6.11e-05 time=18.9s val_psnr=25.70 val_ssim=0.9126 val_lpips=0.0313
# epoch=086 train_mse=0.001364 lr=5.80e-05 time=18.9s val_psnr=26.09 val_ssim=0.9148 val_lpips=0.0317
# epoch=087 train_mse=0.001338 lr=5.51e-05 time=18.9s val_psnr=26.09 val_ssim=0.9155 val_lpips=0.0302
# epoch=088 train_mse=0.001330 lr=5.21e-05 time=18.9s val_psnr=26.10 val_ssim=0.9153 val_lpips=0.0311
# epoch=089 train_mse=0.001322 lr=4.93e-05 time=18.9s val_psnr=26.26 val_ssim=0.9168 val_lpips=0.0302
# saved checkpoint: runs/cifar10_fourier_recon.pt
# epoch=090 train_mse=0.001310 lr=4.65e-05 time=19.0s val_psnr=26.21 val_ssim=0.9164 val_lpips=0.0302
# epoch=091 train_mse=0.001310 lr=4.38e-05 time=19.0s val_psnr=26.15 val_ssim=0.9169 val_lpips=0.0303
# epoch=092 train_mse=0.001301 lr=4.11e-05 time=19.0s val_psnr=26.28 val_ssim=0.9174 val_lpips=0.0293
# saved checkpoint: runs/cifar10_fourier_recon.pt
# epoch=093 train_mse=0.001295 lr=3.86e-05 time=19.0s val_psnr=26.30 val_ssim=0.9176 val_lpips=0.0295
# saved checkpoint: runs/cifar10_fourier_recon.pt
# epoch=094 train_mse=0.001279 lr=3.61e-05 time=19.0s val_psnr=26.30 val_ssim=0.9176 val_lpips=0.0294
# saved checkpoint: runs/cifar10_fourier_recon.pt
# epoch=095 train_mse=0.001274 lr=3.37e-05 time=19.0s val_psnr=26.32 val_ssim=0.9178 val_lpips=0.0288
# saved checkpoint: runs/cifar10_fourier_recon.pt
# epoch=096 train_mse=0.001274 lr=3.14e-05 time=18.9s val_psnr=26.34 val_ssim=0.9183 val_lpips=0.0292
# saved checkpoint: runs/cifar10_fourier_recon.pt
# epoch=097 train_mse=0.001273 lr=2.91e-05 time=18.9s val_psnr=26.35 val_ssim=0.9186 val_lpips=0.0286
# saved checkpoint: runs/cifar10_fourier_recon.pt
# epoch=098 train_mse=0.001260 lr=2.70e-05 time=19.0s val_psnr=26.38 val_ssim=0.9190 val_lpips=0.0287
# saved checkpoint: runs/cifar10_fourier_recon.pt
# epoch=099 train_mse=0.001256 lr=2.49e-05 time=19.0s val_psnr=26.34 val_ssim=0.9188 val_lpips=0.0285
# epoch=100 train_mse=0.001245 lr=2.29e-05 time=19.0s val_psnr=26.36 val_ssim=0.9187 val_lpips=0.0283
# epoch=101 train_mse=0.001247 lr=2.10e-05 time=18.9s val_psnr=26.38 val_ssim=0.9191 val_lpips=0.0279
# epoch=102 train_mse=0.001236 lr=1.92e-05 time=19.0s val_psnr=26.40 val_ssim=0.9193 val_lpips=0.0282
# saved checkpoint: runs/cifar10_fourier_recon.pt
# epoch=103 train_mse=0.001239 lr=1.75e-05 time=18.8s val_psnr=26.35 val_ssim=0.9191 val_lpips=0.0282
# epoch=104 train_mse=0.001229 lr=1.58e-05 time=19.0s val_psnr=26.40 val_ssim=0.9197 val_lpips=0.0281
# epoch=105 train_mse=0.001225 lr=1.43e-05 time=19.1s val_psnr=26.44 val_ssim=0.9199 val_lpips=0.0279
# saved checkpoint: runs/cifar10_fourier_recon.pt
# epoch=106 train_mse=0.001224 lr=1.29e-05 time=19.0s val_psnr=26.44 val_ssim=0.9200 val_lpips=0.0277
# saved checkpoint: runs/cifar10_fourier_recon.pt
# epoch=107 train_mse=0.001216 lr=1.15e-05 time=18.9s val_psnr=26.43 val_ssim=0.9198 val_lpips=0.0277
# epoch=108 train_mse=0.001217 lr=1.03e-05 time=19.0s val_psnr=26.41 val_ssim=0.9197 val_lpips=0.0274
# epoch=109 train_mse=0.001212 lr=9.12e-06 time=19.0s val_psnr=26.46 val_ssim=0.9202 val_lpips=0.0273
# saved checkpoint: runs/cifar10_fourier_recon.pt
# epoch=110 train_mse=0.001212 lr=8.06e-06 time=19.1s val_psnr=26.44 val_ssim=0.9199 val_lpips=0.0280
# epoch=111 train_mse=0.001202 lr=7.10e-06 time=19.0s val_psnr=26.48 val_ssim=0.9205 val_lpips=0.0268
# saved checkpoint: runs/cifar10_fourier_recon.pt
# epoch=112 train_mse=0.001197 lr=6.25e-06 time=18.9s val_psnr=26.48 val_ssim=0.9205 val_lpips=0.0268
# epoch=113 train_mse=0.001203 lr=5.49e-06 time=19.0s val_psnr=26.49 val_ssim=0.9206 val_lpips=0.0269
# saved checkpoint: runs/cifar10_fourier_recon.pt
# epoch=114 train_mse=0.001199 lr=4.83e-06 time=19.0s val_psnr=26.47 val_ssim=0.9202 val_lpips=0.0275
# epoch=115 train_mse=0.001197 lr=4.27e-06 time=18.9s val_psnr=26.47 val_ssim=0.9204 val_lpips=0.0272
# epoch=116 train_mse=0.001194 lr=3.81e-06 time=18.9s val_psnr=26.47 val_ssim=0.9203 val_lpips=0.0273
# epoch=117 train_mse=0.001194 lr=3.46e-06 time=18.9s val_psnr=26.49 val_ssim=0.9204 val_lpips=0.0270
# saved checkpoint: runs/cifar10_fourier_recon.pt
# epoch=118 train_mse=0.001192 lr=3.20e-06 time=18.9s val_psnr=26.49 val_ssim=0.9207 val_lpips=0.0270
# saved checkpoint: runs/cifar10_fourier_recon.pt
# epoch=119 train_mse=0.001187 lr=3.05e-06 time=19.0s val_psnr=26.48 val_ssim=0.9207 val_lpips=0.0268
# epoch=120 train_mse=0.001191 lr=3.00e-06 time=19.0s val_psnr=26.48 val_ssim=0.9206 val_lpips=0.0267

# %%
# ReLU — plain MLP baseline (~30 min)
# !python train_reconstruction.py \
  --dataset cifar10 --arch relu --image-size 32 \
  --epochs 120 --batch-size 128 --samples-per-image 4096 \
  --hidden-dim 128 --depth 4 --latent-dim 512 \
  --lr 3e-4 --weight-decay 1e-7 \
  --num-workers 8 --amp --eval-batches 50 --out-dir ./runs
# Out:
# /home/zihan-gao/miniforge3/envs/dl685/lib/python3.11/site-packages/torchvision/datasets/cifar.py:83: VisibleDeprecationWarning: dtype(): align should be passed as Python or NumPy boolean but got `align=0`. Did you mean to pass a tuple to create a subarray type? (Deprecated NumPy 2.4)
#   entry = pickle.load(f, encoding="latin1")
# Setting up [LPIPS] perceptual loss: trunk [alex], v[0.1], spatial [off]
# /home/zihan-gao/miniforge3/envs/dl685/lib/python3.11/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/zihan-gao/miniforge3/envs/dl685/lib/python3.11/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=AlexNet_Weights.IMAGENET1K_V1`. You can also use `weights=AlexNet_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Loading model from: /home/zihan-gao/miniforge3/envs/dl685/lib/python3.11/site-packages/lpips/weights/v0.1/alex.pth
# device=cuda dataset=cifar10 arch=relu total_generated_params=50307
# epoch=001 train_mse=0.023927 lr=3.00e-04 time=18.1s val_psnr=18.05 val_ssim=0.5848 val_lpips=0.3128
# saved checkpoint: runs/cifar10_relu_recon.pt
# epoch=002 train_mse=0.011875 lr=3.00e-04 time=17.6s val_psnr=18.69 val_ssim=0.6364 val_lpips=0.2519
# saved checkpoint: runs/cifar10_relu_recon.pt
# epoch=003 train_mse=0.009741 lr=3.00e-04 time=17.7s val_psnr=19.38 val_ssim=0.6669 val_lpips=0.2138
# saved checkpoint: runs/cifar10_relu_recon.pt
# epoch=004 train_mse=0.008771 lr=2.99e-04 time=17.6s val_psnr=20.02 val_ssim=0.6972 val_lpips=0.1869
# saved checkpoint: runs/cifar10_relu_recon.pt
# epoch=005 train_mse=0.007784 lr=2.99e-04 time=17.6s val_psnr=19.06 val_ssim=0.7006 val_lpips=0.1824
# epoch=006 train_mse=0.007222 lr=2.98e-04 time=17.7s val_psnr=20.35 val_ssim=0.7265 val_lpips=0.1597
# saved checkpoint: runs/cifar10_relu_recon.pt
# epoch=007 train_mse=0.006678 lr=2.98e-04 time=17.7s val_psnr=20.26 val_ssim=0.7311 val_lpips=0.1490
# epoch=008 train_mse=0.006324 lr=2.97e-04 time=17.8s val_psnr=21.08 val_ssim=0.7543 val_lpips=0.1411
# saved checkpoint: runs/cifar10_relu_recon.pt
# epoch=009 train_mse=0.005852 lr=2.96e-04 time=17.7s val_psnr=21.25 val_ssim=0.7611 val_lpips=0.1375
# saved checkpoint: runs/cifar10_relu_recon.pt
# epoch=010 train_mse=0.005719 lr=2.95e-04 time=17.8s val_psnr=21.27 val_ssim=0.7662 val_lpips=0.1315
# saved checkpoint: runs/cifar10_relu_recon.pt
# epoch=011 train_mse=0.005335 lr=2.94e-04 time=17.7s val_psnr=21.55 val_ssim=0.7757 val_lpips=0.1246
# saved checkpoint: runs/cifar10_relu_recon.pt
# epoch=012 train_mse=0.004932 lr=2.93e-04 time=17.8s val_psnr=21.92 val_ssim=0.7903 val_lpips=0.1171
# saved checkpoint: runs/cifar10_relu_recon.pt
# epoch=013 train_mse=0.004974 lr=2.91e-04 time=17.7s val_psnr=21.75 val_ssim=0.7906 val_lpips=0.1185
# epoch=014 train_mse=0.004742 lr=2.90e-04 time=17.7s val_psnr=21.75 val_ssim=0.7905 val_lpips=0.1152
# epoch=015 train_mse=0.004605 lr=2.89e-04 time=17.8s val_psnr=22.13 val_ssim=0.8027 val_lpips=0.1094
# saved checkpoint: runs/cifar10_relu_recon.pt
# epoch=016 train_mse=0.004476 lr=2.87e-04 time=17.8s val_psnr=22.37 val_ssim=0.8107 val_lpips=0.1042
# saved checkpoint: runs/cifar10_relu_recon.pt
# epoch=017 train_mse=0.004258 lr=2.86e-04 time=17.7s val_psnr=22.01 val_ssim=0.8084 val_lpips=0.1048
# epoch=018 train_mse=0.004111 lr=2.84e-04 time=17.7s val_psnr=22.64 val_ssim=0.8183 val_lpips=0.0994
# saved checkpoint: runs/cifar10_relu_recon.pt
# epoch=019 train_mse=0.004112 lr=2.82e-04 time=17.8s val_psnr=21.67 val_ssim=0.7992 val_lpips=0.1052
# epoch=020 train_mse=0.003863 lr=2.80e-04 time=18.0s val_psnr=22.68 val_ssim=0.8234 val_lpips=0.0967
# saved checkpoint: runs/cifar10_relu_recon.pt
# epoch=021 train_mse=0.003707 lr=2.78e-04 time=17.9s val_psnr=22.52 val_ssim=0.8255 val_lpips=0.0953
# epoch=022 train_mse=0.003722 lr=2.76e-04 time=17.8s val_psnr=22.89 val_ssim=0.8322 val_lpips=0.0925
# saved checkpoint: runs/cifar10_relu_recon.pt
# epoch=023 train_mse=0.003549 lr=2.74e-04 time=17.7s val_psnr=22.92 val_ssim=0.8345 val_lpips=0.0924
# saved checkpoint: runs/cifar10_relu_recon.pt
# epoch=024 train_mse=0.003454 lr=2.72e-04 time=17.7s val_psnr=22.91 val_ssim=0.8312 val_lpips=0.0913
# epoch=025 train_mse=0.003308 lr=2.69e-04 time=17.7s val_psnr=23.32 val_ssim=0.8435 val_lpips=0.0868
# saved checkpoint: runs/cifar10_relu_recon.pt
# epoch=026 train_mse=0.003372 lr=2.67e-04 time=17.6s val_psnr=23.05 val_ssim=0.8413 val_lpips=0.0861
# epoch=027 train_mse=0.003213 lr=2.64e-04 time=17.5s val_psnr=23.07 val_ssim=0.8392 val_lpips=0.0874
# epoch=028 train_mse=0.003287 lr=2.62e-04 time=17.5s val_psnr=23.36 val_ssim=0.8481 val_lpips=0.0863
# saved checkpoint: runs/cifar10_relu_recon.pt
# epoch=029 train_mse=0.003070 lr=2.59e-04 time=17.5s val_psnr=23.43 val_ssim=0.8477 val_lpips=0.0822
# saved checkpoint: runs/cifar10_relu_recon.pt
# epoch=030 train_mse=0.003148 lr=2.57e-04 time=17.5s val_psnr=23.33 val_ssim=0.8469 val_lpips=0.0840
# epoch=031 train_mse=0.002968 lr=2.54e-04 time=17.6s val_psnr=23.10 val_ssim=0.8471 val_lpips=0.0853
# epoch=032 train_mse=0.002998 lr=2.51e-04 time=17.6s val_psnr=23.46 val_ssim=0.8517 val_lpips=0.0814
# saved checkpoint: runs/cifar10_relu_recon.pt
# epoch=033 train_mse=0.002919 lr=2.48e-04 time=18.0s val_psnr=23.22 val_ssim=0.8494 val_lpips=0.0812
# epoch=034 train_mse=0.002890 lr=2.45e-04 time=18.1s val_psnr=23.25 val_ssim=0.8525 val_lpips=0.0778
# epoch=035 train_mse=0.002966 lr=2.42e-04 time=17.7s val_psnr=23.56 val_ssim=0.8555 val_lpips=0.0789
# saved checkpoint: runs/cifar10_relu_recon.pt
# epoch=036 train_mse=0.002791 lr=2.39e-04 time=17.7s val_psnr=23.87 val_ssim=0.8632 val_lpips=0.0732
# saved checkpoint: runs/cifar10_relu_recon.pt
# epoch=037 train_mse=0.002694 lr=2.36e-04 time=17.7s val_psnr=23.61 val_ssim=0.8588 val_lpips=0.0769
# epoch=038 train_mse=0.002667 lr=2.32e-04 time=17.7s val_psnr=23.81 val_ssim=0.8618 val_lpips=0.0754
# epoch=039 train_mse=0.002789 lr=2.29e-04 time=17.8s val_psnr=23.85 val_ssim=0.8629 val_lpips=0.0733
# epoch=040 train_mse=0.002568 lr=2.26e-04 time=17.7s val_psnr=23.87 val_ssim=0.8668 val_lpips=0.0705
# saved checkpoint: runs/cifar10_relu_recon.pt
# epoch=041 train_mse=0.002550 lr=2.22e-04 time=17.5s val_psnr=24.11 val_ssim=0.8700 val_lpips=0.0702
# saved checkpoint: runs/cifar10_relu_recon.pt
# epoch=042 train_mse=0.002532 lr=2.19e-04 time=17.6s val_psnr=24.23 val_ssim=0.8715 val_lpips=0.0697
# saved checkpoint: runs/cifar10_relu_recon.pt
# epoch=043 train_mse=0.002518 lr=2.15e-04 time=17.6s val_psnr=24.14 val_ssim=0.8691 val_lpips=0.0700
# epoch=044 train_mse=0.002416 lr=2.12e-04 time=17.4s val_psnr=24.34 val_ssim=0.8755 val_lpips=0.0672
# saved checkpoint: runs/cifar10_relu_recon.pt
# epoch=045 train_mse=0.002392 lr=2.08e-04 time=17.4s val_psnr=24.24 val_ssim=0.8729 val_lpips=0.0685
# epoch=046 train_mse=0.002344 lr=2.05e-04 time=17.3s val_psnr=24.22 val_ssim=0.8738 val_lpips=0.0659
# epoch=047 train_mse=0.002482 lr=2.01e-04 time=17.3s val_psnr=23.76 val_ssim=0.8672 val_lpips=0.0698
# epoch=048 train_mse=0.002293 lr=1.97e-04 time=17.3s val_psnr=24.27 val_ssim=0.8760 val_lpips=0.0646
# epoch=049 train_mse=0.002294 lr=1.94e-04 time=17.3s val_psnr=24.37 val_ssim=0.8775 val_lpips=0.0664
# saved checkpoint: runs/cifar10_relu_recon.pt
# epoch=050 train_mse=0.002260 lr=1.90e-04 time=17.3s val_psnr=23.80 val_ssim=0.8729 val_lpips=0.0641
# epoch=051 train_mse=0.002268 lr=1.86e-04 time=17.3s val_psnr=24.52 val_ssim=0.8806 val_lpips=0.0632
# saved checkpoint: runs/cifar10_relu_recon.pt
# epoch=052 train_mse=0.002183 lr=1.82e-04 time=17.2s val_psnr=24.56 val_ssim=0.8808 val_lpips=0.0628
# saved checkpoint: runs/cifar10_relu_recon.pt
# epoch=053 train_mse=0.002192 lr=1.79e-04 time=17.3s val_psnr=24.44 val_ssim=0.8782 val_lpips=0.0639
# epoch=054 train_mse=0.002148 lr=1.75e-04 time=17.4s val_psnr=24.55 val_ssim=0.8821 val_lpips=0.0616
# epoch=055 train_mse=0.002170 lr=1.71e-04 time=17.4s val_psnr=24.64 val_ssim=0.8829 val_lpips=0.0607
# saved checkpoint: runs/cifar10_relu_recon.pt
# epoch=056 train_mse=0.002116 lr=1.67e-04 time=17.4s val_psnr=24.47 val_ssim=0.8828 val_lpips=0.0609
# epoch=057 train_mse=0.002100 lr=1.63e-04 time=17.4s val_psnr=24.66 val_ssim=0.8842 val_lpips=0.0604
# saved checkpoint: runs/cifar10_relu_recon.pt
# epoch=058 train_mse=0.002097 lr=1.59e-04 time=17.5s val_psnr=24.43 val_ssim=0.8851 val_lpips=0.0630
# epoch=059 train_mse=0.002038 lr=1.55e-04 time=17.4s val_psnr=24.86 val_ssim=0.8879 val_lpips=0.0586
# saved checkpoint: runs/cifar10_relu_recon.pt
# epoch=060 train_mse=0.001994 lr=1.51e-04 time=17.4s val_psnr=24.25 val_ssim=0.8812 val_lpips=0.0597
# epoch=061 train_mse=0.002031 lr=1.48e-04 time=17.3s val_psnr=24.58 val_ssim=0.8837 val_lpips=0.0590
# epoch=062 train_mse=0.001984 lr=1.44e-04 time=17.5s val_psnr=24.79 val_ssim=0.8874 val_lpips=0.0582
# epoch=063 train_mse=0.002012 lr=1.40e-04 time=17.4s val_psnr=24.76 val_ssim=0.8884 val_lpips=0.0569
# epoch=064 train_mse=0.001927 lr=1.36e-04 time=17.4s val_psnr=24.98 val_ssim=0.8898 val_lpips=0.0575
# saved checkpoint: runs/cifar10_relu_recon.pt
# epoch=065 train_mse=0.001940 lr=1.32e-04 time=17.5s val_psnr=24.69 val_ssim=0.8884 val_lpips=0.0567
# epoch=066 train_mse=0.001943 lr=1.28e-04 time=17.5s val_psnr=24.85 val_ssim=0.8887 val_lpips=0.0565
# epoch=067 train_mse=0.001941 lr=1.24e-04 time=17.6s val_psnr=24.57 val_ssim=0.8860 val_lpips=0.0587
# epoch=068 train_mse=0.001870 lr=1.21e-04 time=17.5s val_psnr=24.81 val_ssim=0.8881 val_lpips=0.0561
# epoch=069 train_mse=0.001847 lr=1.17e-04 time=17.5s val_psnr=24.80 val_ssim=0.8918 val_lpips=0.0536
# epoch=070 train_mse=0.001904 lr=1.13e-04 time=17.6s val_psnr=24.97 val_ssim=0.8922 val_lpips=0.0547
# epoch=071 train_mse=0.001850 lr=1.09e-04 time=17.5s val_psnr=25.03 val_ssim=0.8916 val_lpips=0.0556
# saved checkpoint: runs/cifar10_relu_recon.pt
# epoch=072 train_mse=0.001817 lr=1.06e-04 time=17.4s val_psnr=25.13 val_ssim=0.8948 val_lpips=0.0535
# saved checkpoint: runs/cifar10_relu_recon.pt
# epoch=073 train_mse=0.001817 lr=1.02e-04 time=17.4s val_psnr=24.93 val_ssim=0.8910 val_lpips=0.0552
# epoch=074 train_mse=0.001799 lr=9.83e-05 time=17.5s val_psnr=25.19 val_ssim=0.8946 val_lpips=0.0533
# saved checkpoint: runs/cifar10_relu_recon.pt
# epoch=075 train_mse=0.001794 lr=9.47e-05 time=17.5s val_psnr=25.17 val_ssim=0.8945 val_lpips=0.0524
# epoch=076 train_mse=0.001738 lr=9.11e-05 time=17.4s val_psnr=25.24 val_ssim=0.8968 val_lpips=0.0515
# saved checkpoint: runs/cifar10_relu_recon.pt
# epoch=077 train_mse=0.001764 lr=8.76e-05 time=17.3s val_psnr=25.23 val_ssim=0.8954 val_lpips=0.0520
# epoch=078 train_mse=0.001718 lr=8.41e-05 time=17.3s val_psnr=25.26 val_ssim=0.8964 val_lpips=0.0514
# saved checkpoint: runs/cifar10_relu_recon.pt
# epoch=079 train_mse=0.001709 lr=8.06e-05 time=17.3s val_psnr=25.18 val_ssim=0.8973 val_lpips=0.0518
# epoch=080 train_mse=0.001721 lr=7.73e-05 time=17.3s val_psnr=25.23 val_ssim=0.8981 val_lpips=0.0505
# epoch=081 train_mse=0.001697 lr=7.39e-05 time=17.3s val_psnr=25.25 val_ssim=0.8970 val_lpips=0.0520
# epoch=082 train_mse=0.001715 lr=7.06e-05 time=17.3s val_psnr=25.27 val_ssim=0.8972 val_lpips=0.0504
# saved checkpoint: runs/cifar10_relu_recon.pt
# epoch=083 train_mse=0.001665 lr=6.74e-05 time=17.2s val_psnr=25.31 val_ssim=0.8981 val_lpips=0.0499
# saved checkpoint: runs/cifar10_relu_recon.pt
# epoch=084 train_mse=0.001672 lr=6.42e-05 time=17.2s val_psnr=25.06 val_ssim=0.8963 val_lpips=0.0503
# epoch=085 train_mse=0.001659 lr=6.11e-05 time=17.3s val_psnr=25.26 val_ssim=0.8989 val_lpips=0.0504
# epoch=086 train_mse=0.001645 lr=5.80e-05 time=17.3s val_psnr=25.41 val_ssim=0.8997 val_lpips=0.0497
# saved checkpoint: runs/cifar10_relu_recon.pt
# epoch=087 train_mse=0.001652 lr=5.51e-05 time=17.4s val_psnr=25.37 val_ssim=0.8993 val_lpips=0.0495
# epoch=088 train_mse=0.001628 lr=5.21e-05 time=17.4s val_psnr=25.30 val_ssim=0.8990 val_lpips=0.0496
# epoch=089 train_mse=0.001618 lr=4.93e-05 time=17.2s val_psnr=25.44 val_ssim=0.9000 val_lpips=0.0492
# saved checkpoint: runs/cifar10_relu_recon.pt
# epoch=090 train_mse=0.001604 lr=4.65e-05 time=16.3s val_psnr=25.41 val_ssim=0.9003 val_lpips=0.0483
# epoch=091 train_mse=0.001599 lr=4.38e-05 time=16.3s val_psnr=25.34 val_ssim=0.8998 val_lpips=0.0489
# epoch=092 train_mse=0.001588 lr=4.11e-05 time=16.3s val_psnr=25.50 val_ssim=0.9021 val_lpips=0.0475
# saved checkpoint: runs/cifar10_relu_recon.pt
# epoch=093 train_mse=0.001581 lr=3.86e-05 time=16.7s val_psnr=25.42 val_ssim=0.9016 val_lpips=0.0480
# epoch=094 train_mse=0.001569 lr=3.61e-05 time=16.7s val_psnr=25.49 val_ssim=0.9014 val_lpips=0.0480
# epoch=095 train_mse=0.001563 lr=3.37e-05 time=16.7s val_psnr=25.51 val_ssim=0.9015 val_lpips=0.0477
# saved checkpoint: runs/cifar10_relu_recon.pt
# epoch=096 train_mse=0.001546 lr=3.14e-05 time=16.6s val_psnr=25.43 val_ssim=0.9014 val_lpips=0.0474
# epoch=097 train_mse=0.001559 lr=2.91e-05 time=16.6s val_psnr=25.54 val_ssim=0.9027 val_lpips=0.0472
# saved checkpoint: runs/cifar10_relu_recon.pt
# epoch=098 train_mse=0.001541 lr=2.70e-05 time=16.6s val_psnr=25.49 val_ssim=0.9024 val_lpips=0.0467
# epoch=099 train_mse=0.001547 lr=2.49e-05 time=16.6s val_psnr=25.55 val_ssim=0.9026 val_lpips=0.0470
# saved checkpoint: runs/cifar10_relu_recon.pt
# epoch=100 train_mse=0.001529 lr=2.29e-05 time=16.6s val_psnr=25.55 val_ssim=0.9025 val_lpips=0.0469
# saved checkpoint: runs/cifar10_relu_recon.pt
# epoch=101 train_mse=0.001521 lr=2.10e-05 time=16.7s val_psnr=25.58 val_ssim=0.9032 val_lpips=0.0463
# saved checkpoint: runs/cifar10_relu_recon.pt
# epoch=102 train_mse=0.001519 lr=1.92e-05 time=16.7s val_psnr=25.49 val_ssim=0.9017 val_lpips=0.0466
# epoch=103 train_mse=0.001506 lr=1.75e-05 time=16.8s val_psnr=25.59 val_ssim=0.9036 val_lpips=0.0459
# saved checkpoint: runs/cifar10_relu_recon.pt
# epoch=104 train_mse=0.001508 lr=1.58e-05 time=16.7s val_psnr=25.57 val_ssim=0.9030 val_lpips=0.0459
# epoch=105 train_mse=0.001501 lr=1.43e-05 time=16.6s val_psnr=25.60 val_ssim=0.9030 val_lpips=0.0461
# saved checkpoint: runs/cifar10_relu_recon.pt
# epoch=106 train_mse=0.001504 lr=1.29e-05 time=16.6s val_psnr=25.59 val_ssim=0.9028 val_lpips=0.0463
# epoch=107 train_mse=0.001496 lr=1.15e-05 time=16.6s val_psnr=25.61 val_ssim=0.9037 val_lpips=0.0456
# saved checkpoint: runs/cifar10_relu_recon.pt
# epoch=108 train_mse=0.001496 lr=1.03e-05 time=16.6s val_psnr=25.65 val_ssim=0.9043 val_lpips=0.0454
# saved checkpoint: runs/cifar10_relu_recon.pt
# epoch=109 train_mse=0.001493 lr=9.12e-06 time=16.7s val_psnr=25.62 val_ssim=0.9035 val_lpips=0.0457
# epoch=110 train_mse=0.001488 lr=8.06e-06 time=16.8s val_psnr=25.64 val_ssim=0.9039 val_lpips=0.0458
# epoch=111 train_mse=0.001476 lr=7.10e-06 time=16.7s val_psnr=25.66 val_ssim=0.9041 val_lpips=0.0456
# saved checkpoint: runs/cifar10_relu_recon.pt
# epoch=112 train_mse=0.001476 lr=6.25e-06 time=16.7s val_psnr=25.65 val_ssim=0.9042 val_lpips=0.0454
# epoch=113 train_mse=0.001474 lr=5.49e-06 time=16.7s val_psnr=25.65 val_ssim=0.9041 val_lpips=0.0451
# epoch=114 train_mse=0.001471 lr=4.83e-06 time=16.6s val_psnr=25.67 val_ssim=0.9045 val_lpips=0.0452
# saved checkpoint: runs/cifar10_relu_recon.pt
# epoch=115 train_mse=0.001469 lr=4.27e-06 time=16.6s val_psnr=25.67 val_ssim=0.9044 val_lpips=0.0453
# epoch=116 train_mse=0.001463 lr=3.81e-06 time=16.6s val_psnr=25.64 val_ssim=0.9041 val_lpips=0.0455
# epoch=117 train_mse=0.001464 lr=3.46e-06 time=16.6s val_psnr=25.66 val_ssim=0.9044 val_lpips=0.0451
# epoch=118 train_mse=0.001461 lr=3.20e-06 time=16.6s val_psnr=25.66 val_ssim=0.9043 val_lpips=0.0452
# epoch=119 train_mse=0.001461 lr=3.05e-06 time=16.6s val_psnr=25.64 val_ssim=0.9038 val_lpips=0.0456
# epoch=120 train_mse=0.001461 lr=3.00e-06 time=16.6s val_psnr=25.67 val_ssim=0.9044 val_lpips=0.0450
# saved checkpoint: runs/cifar10_relu_recon.pt

# %%
import json, glob
import matplotlib.pyplot as plt

fig, axes = plt.subplots(1, 3, figsize=(15, 4))
for path in sorted(glob.glob('./runs/cifar10_*_recon_metrics.jsonl')):
    arch = path.split('cifar10_')[1].split('_recon')[0]
    rows = [json.loads(l) for l in open(path)]
    for ax, m, lab in zip(axes, ['psnr', 'ssim', 'lpips'], ['PSNR (dB)↑', 'SSIM↑', 'LPIPS↓']):
        vals = [r[m] for r in rows if m in r]
        ax.plot(range(1, len(vals)+1), vals, label=arch)
        ax.set_xlabel('Epoch'); ax.set_ylabel(lab); ax.legend(); ax.grid(True)
plt.suptitle('CIFAR-10 — Validation Metrics')
plt.tight_layout()
plt.savefig('./runs/cifar10_training_curves.png', dpi=150)
plt.show()

# %% [markdown]
# ---
# ## Section 2 — CIFAR-10 Downstream Classification
#
# Linear probe on three feature types:
# - **latent** — hypernetwork bottleneck z (512-dim)
# - **theta** — full generated INR weights (~50k-dim)
# - **pixels** — raw flattened pixels (3072-dim) — baseline

# %%
# !python train_downstream_classifier.py \
  --recon-ckpt ./runs/cifar10_siren_recon.pt \
  --feature-type latent --cls-epochs 100 \
  --out-path ./runs/cifar10_siren_latent_cls.pt \
  --max-train-samples 0 --max-test-samples 0
# Out:
# /home/zihan-gao/miniforge3/envs/dl685/lib/python3.11/site-packages/torchvision/datasets/cifar.py:83: VisibleDeprecationWarning: dtype(): align should be passed as Python or NumPy boolean but got `align=0`. Did you mean to pass a tuple to create a subarray type? (Deprecated NumPy 2.4)
#   entry = pickle.load(f, encoding="latin1")
# epoch=001 val_acc=32.95% best_acc=32.95%
# epoch=002 val_acc=34.56% best_acc=34.56%
# epoch=003 val_acc=35.33% best_acc=35.33%
# epoch=004 val_acc=36.26% best_acc=36.26%
# epoch=005 val_acc=37.09% best_acc=37.09%
# epoch=006 val_acc=37.71% best_acc=37.71%
# epoch=007 val_acc=38.21% best_acc=38.21%
# epoch=008 val_acc=39.00% best_acc=39.00%
# epoch=009 val_acc=38.64% best_acc=39.00%
# epoch=010 val_acc=38.83% best_acc=39.00%
# epoch=011 val_acc=39.29% best_acc=39.29%
# epoch=012 val_acc=39.84% best_acc=39.84%
# epoch=013 val_acc=39.94% best_acc=39.94%
# epoch=014 val_acc=40.33% best_acc=40.33%
# epoch=015 val_acc=40.66% best_acc=40.66%
# epoch=016 val_acc=41.25% best_acc=41.25%
# epoch=017 val_acc=41.75% best_acc=41.75%
# epoch=018 val_acc=40.78% best_acc=41.75%
# epoch=019 val_acc=41.41% best_acc=41.75%
# epoch=020 val_acc=42.08% best_acc=42.08%
# epoch=021 val_acc=42.06% best_acc=42.08%
# epoch=022 val_acc=42.36% best_acc=42.36%
# epoch=023 val_acc=41.87% best_acc=42.36%
# epoch=024 val_acc=42.27% best_acc=42.36%
# epoch=025 val_acc=42.74% best_acc=42.74%
# epoch=026 val_acc=42.78% best_acc=42.78%
# epoch=027 val_acc=42.84% best_acc=42.84%
# epoch=028 val_acc=43.46% best_acc=43.46%
# epoch=029 val_acc=43.00% best_acc=43.46%
# epoch=030 val_acc=43.53% best_acc=43.53%
# epoch=031 val_acc=43.47% best_acc=43.53%
# epoch=032 val_acc=43.42% best_acc=43.53%
# epoch=033 val_acc=43.60% best_acc=43.60%
# epoch=034 val_acc=43.29% best_acc=43.60%
# epoch=035 val_acc=44.09% best_acc=44.09%
# epoch=036 val_acc=43.79% best_acc=44.09%
# epoch=037 val_acc=44.09% best_acc=44.09%
# epoch=038 val_acc=43.75% best_acc=44.09%
# epoch=039 val_acc=43.27% best_acc=44.09%
# epoch=040 val_acc=43.96% best_acc=44.09%
# epoch=041 val_acc=44.02% best_acc=44.09%
# epoch=042 val_acc=44.21% best_acc=44.21%
# epoch=043 val_acc=44.02% best_acc=44.21%
# epoch=044 val_acc=43.83% best_acc=44.21%
# epoch=045 val_acc=44.48% best_acc=44.48%
# epoch=046 val_acc=43.95% best_acc=44.48%
# epoch=047 val_acc=44.36% best_acc=44.48%
# epoch=048 val_acc=44.35% best_acc=44.48%
# epoch=049 val_acc=44.47% best_acc=44.48%
# epoch=050 val_acc=44.66% best_acc=44.66%
# epoch=051 val_acc=44.23% best_acc=44.66%
# epoch=052 val_acc=44.57% best_acc=44.66%
# epoch=053 val_acc=43.96% best_acc=44.66%
# epoch=054 val_acc=44.69% best_acc=44.69%
# epoch=055 val_acc=44.50% best_acc=44.69%
# epoch=056 val_acc=44.78% best_acc=44.78%
# epoch=057 val_acc=44.78% best_acc=44.78%
# epoch=058 val_acc=44.66% best_acc=44.78%
# epoch=059 val_acc=44.32% best_acc=44.78%
# epoch=060 val_acc=44.09% best_acc=44.78%
# epoch=061 val_acc=44.60% best_acc=44.78%
# epoch=062 val_acc=44.73% best_acc=44.78%
# epoch=063 val_acc=44.58% best_acc=44.78%
# epoch=064 val_acc=45.02% best_acc=45.02%
# epoch=065 val_acc=44.95% best_acc=45.02%
# epoch=066 val_acc=44.53% best_acc=45.02%
# epoch=067 val_acc=44.88% best_acc=45.02%
# epoch=068 val_acc=45.28% best_acc=45.28%
# epoch=069 val_acc=44.68% best_acc=45.28%
# epoch=070 val_acc=44.79% best_acc=45.28%
# epoch=071 val_acc=44.11% best_acc=45.28%
# epoch=072 val_acc=44.82% best_acc=45.28%
# epoch=073 val_acc=45.24% best_acc=45.28%
# epoch=074 val_acc=44.37% best_acc=45.28%
# epoch=075 val_acc=45.22% best_acc=45.28%
# epoch=076 val_acc=45.16% best_acc=45.28%
# epoch=077 val_acc=45.22% best_acc=45.28%
# epoch=078 val_acc=45.30% best_acc=45.30%
# epoch=079 val_acc=45.28% best_acc=45.30%
# epoch=080 val_acc=45.19% best_acc=45.30%
# epoch=081 val_acc=45.13% best_acc=45.30%
# epoch=082 val_acc=45.01% best_acc=45.30%
# epoch=083 val_acc=45.29% best_acc=45.30%
# epoch=084 val_acc=44.89% best_acc=45.30%
# epoch=085 val_acc=45.31% best_acc=45.31%
# epoch=086 val_acc=44.84% best_acc=45.31%
# epoch=087 val_acc=45.25% best_acc=45.31%
# epoch=088 val_acc=44.89% best_acc=45.31%
# epoch=089 val_acc=44.92% best_acc=45.31%
# epoch=090 val_acc=45.20% best_acc=45.31%
# epoch=091 val_acc=45.49% best_acc=45.49%
# epoch=092 val_acc=45.04% best_acc=45.49%
# epoch=093 val_acc=45.19% best_acc=45.49%
# epoch=094 val_acc=45.45% best_acc=45.49%
# epoch=095 val_acc=45.38% best_acc=45.49%
# epoch=096 val_acc=45.29% best_acc=45.49%
# epoch=097 val_acc=45.36% best_acc=45.49%
# epoch=098 val_acc=45.25% best_acc=45.49%
# epoch=099 val_acc=45.25% best_acc=45.49%
# epoch=100 val_acc=45.23% best_acc=45.49%
# saved classifier: runs/cifar10_siren_latent_cls.pt

# %%
# !python train_downstream_classifier.py \
  --recon-ckpt ./runs/cifar10_siren_recon.pt \
  --feature-type theta --cls-epochs 100 \
  --out-path ./runs/cifar10_siren_theta_cls.pt \
  --max-train-samples 0 --max-test-samples 0
# Out:
# /home/zihan-gao/miniforge3/envs/dl685/lib/python3.11/site-packages/torchvision/datasets/cifar.py:83: VisibleDeprecationWarning: dtype(): align should be passed as Python or NumPy boolean but got `align=0`. Did you mean to pass a tuple to create a subarray type? (Deprecated NumPy 2.4)
#   entry = pickle.load(f, encoding="latin1")
# epoch=001 val_acc=32.53% best_acc=32.53%
# epoch=002 val_acc=30.85% best_acc=32.53%
# epoch=003 val_acc=19.98% best_acc=32.53%
# epoch=004 val_acc=27.43% best_acc=32.53%
# epoch=005 val_acc=28.93% best_acc=32.53%
# epoch=006 val_acc=36.01% best_acc=36.01%
# epoch=007 val_acc=34.62% best_acc=36.01%
# epoch=008 val_acc=27.66% best_acc=36.01%
# epoch=009 val_acc=31.45% best_acc=36.01%
# epoch=010 val_acc=27.14% best_acc=36.01%
# epoch=011 val_acc=33.64% best_acc=36.01%
# epoch=012 val_acc=37.34% best_acc=37.34%
# epoch=013 val_acc=23.34% best_acc=37.34%
# epoch=014 val_acc=34.39% best_acc=37.34%
# epoch=015 val_acc=37.25% best_acc=37.34%
# epoch=016 val_acc=39.64% best_acc=39.64%
# epoch=017 val_acc=35.39% best_acc=39.64%
# epoch=018 val_acc=17.83% best_acc=39.64%
# epoch=019 val_acc=33.06% best_acc=39.64%
# epoch=020 val_acc=35.96% best_acc=39.64%
# epoch=021 val_acc=24.07% best_acc=39.64%
# epoch=022 val_acc=37.90% best_acc=39.64%
# epoch=023 val_acc=39.69% best_acc=39.69%
# epoch=024 val_acc=39.41% best_acc=39.69%
# epoch=025 val_acc=34.46% best_acc=39.69%
# epoch=026 val_acc=38.29% best_acc=39.69%
# epoch=027 val_acc=37.27% best_acc=39.69%
# epoch=028 val_acc=40.29% best_acc=40.29%
# epoch=029 val_acc=38.03% best_acc=40.29%
# epoch=030 val_acc=40.14% best_acc=40.29%
# epoch=031 val_acc=24.60% best_acc=40.29%
# epoch=032 val_acc=33.43% best_acc=40.29%
# epoch=033 val_acc=33.16% best_acc=40.29%
# epoch=034 val_acc=34.00% best_acc=40.29%
# epoch=035 val_acc=34.04% best_acc=40.29%
# epoch=036 val_acc=33.99% best_acc=40.29%
# epoch=037 val_acc=30.30% best_acc=40.29%
# epoch=038 val_acc=36.27% best_acc=40.29%
# epoch=039 val_acc=35.76% best_acc=40.29%
# epoch=040 val_acc=24.83% best_acc=40.29%
# epoch=041 val_acc=43.73% best_acc=43.73%
# epoch=042 val_acc=41.50% best_acc=43.73%
# epoch=043 val_acc=20.53% best_acc=43.73%
# epoch=044 val_acc=37.27% best_acc=43.73%
# epoch=045 val_acc=42.44% best_acc=43.73%
# epoch=046 val_acc=35.33% best_acc=43.73%
# epoch=047 val_acc=35.53% best_acc=43.73%
# epoch=048 val_acc=42.11% best_acc=43.73%
# epoch=049 val_acc=37.60% best_acc=43.73%
# epoch=050 val_acc=38.58% best_acc=43.73%
# epoch=051 val_acc=40.68% best_acc=43.73%
# epoch=052 val_acc=37.01% best_acc=43.73%
# epoch=053 val_acc=39.18% best_acc=43.73%
# epoch=054 val_acc=37.59% best_acc=43.73%
# epoch=055 val_acc=30.50% best_acc=43.73%
# epoch=056 val_acc=11.77% best_acc=43.73%
# epoch=057 val_acc=33.04% best_acc=43.73%
# epoch=058 val_acc=37.70% best_acc=43.73%
# epoch=059 val_acc=38.19% best_acc=43.73%
# epoch=060 val_acc=32.84% best_acc=43.73%
# epoch=061 val_acc=37.21% best_acc=43.73%
# epoch=062 val_acc=25.55% best_acc=43.73%
# epoch=063 val_acc=43.23% best_acc=43.73%
# epoch=064 val_acc=33.21% best_acc=43.73%
# epoch=065 val_acc=39.01% best_acc=43.73%
# epoch=066 val_acc=27.49% best_acc=43.73%
# epoch=067 val_acc=39.12% best_acc=43.73%
# epoch=068 val_acc=44.46% best_acc=44.46%
# epoch=069 val_acc=35.82% best_acc=44.46%
# epoch=070 val_acc=27.76% best_acc=44.46%
# epoch=071 val_acc=40.54% best_acc=44.46%
# epoch=072 val_acc=20.37% best_acc=44.46%
# epoch=073 val_acc=38.96% best_acc=44.46%
# epoch=074 val_acc=38.26% best_acc=44.46%
# epoch=075 val_acc=32.69% best_acc=44.46%
# epoch=076 val_acc=39.23% best_acc=44.46%
# epoch=077 val_acc=39.00% best_acc=44.46%
# epoch=078 val_acc=36.71% best_acc=44.46%
# epoch=079 val_acc=28.19% best_acc=44.46%
# epoch=080 val_acc=38.59% best_acc=44.46%
# epoch=081 val_acc=39.16% best_acc=44.46%
# epoch=082 val_acc=39.61% best_acc=44.46%
# epoch=083 val_acc=37.67% best_acc=44.46%
# epoch=084 val_acc=37.73% best_acc=44.46%
# epoch=085 val_acc=34.26% best_acc=44.46%
# epoch=086 val_acc=40.03% best_acc=44.46%
# epoch=087 val_acc=29.27% best_acc=44.46%
# epoch=088 val_acc=32.40% best_acc=44.46%
# epoch=089 val_acc=38.52% best_acc=44.46%
# epoch=090 val_acc=26.06% best_acc=44.46%
# epoch=091 val_acc=33.74% best_acc=44.46%
# epoch=092 val_acc=39.15% best_acc=44.46%
# epoch=093 val_acc=28.01% best_acc=44.46%
# epoch=094 val_acc=41.79% best_acc=44.46%
# epoch=095 val_acc=39.50% best_acc=44.46%
# epoch=096 val_acc=41.01% best_acc=44.46%
# epoch=097 val_acc=33.23% best_acc=44.46%
# epoch=098 val_acc=42.19% best_acc=44.46%
# epoch=099 val_acc=34.29% best_acc=44.46%
# epoch=100 val_acc=29.46% best_acc=44.46%
# saved classifier: runs/cifar10_siren_theta_cls.pt

# %%
# Raw pixel baseline — no checkpoint needed
# !python train_downstream_classifier.py \
  --feature-type pixels --cls-epochs 100 \
  --out-path ./runs/cifar10_pixels_cls.pt \
  --max-train-samples 0 --max-test-samples 0
# Out:
# /home/zihan-gao/miniforge3/envs/dl685/lib/python3.11/site-packages/torchvision/datasets/cifar.py:83: VisibleDeprecationWarning: dtype(): align should be passed as Python or NumPy boolean but got `align=0`. Did you mean to pass a tuple to create a subarray type? (Deprecated NumPy 2.4)
#   entry = pickle.load(f, encoding="latin1")
# epoch=001 val_acc=35.40% best_acc=35.40%
# epoch=002 val_acc=37.33% best_acc=37.33%
# epoch=003 val_acc=38.67% best_acc=38.67%
# epoch=004 val_acc=38.08% best_acc=38.67%
# epoch=005 val_acc=38.64% best_acc=38.67%
# epoch=006 val_acc=38.43% best_acc=38.67%
# epoch=007 val_acc=38.14% best_acc=38.67%
# epoch=008 val_acc=38.12% best_acc=38.67%
# epoch=009 val_acc=38.24% best_acc=38.67%
# epoch=010 val_acc=39.12% best_acc=39.12%
# epoch=011 val_acc=36.94% best_acc=39.12%
# epoch=012 val_acc=38.89% best_acc=39.12%
# epoch=013 val_acc=38.45% best_acc=39.12%
# epoch=014 val_acc=38.99% best_acc=39.12%
# epoch=015 val_acc=38.09% best_acc=39.12%
# epoch=016 val_acc=37.52% best_acc=39.12%
# epoch=017 val_acc=38.30% best_acc=39.12%
# epoch=018 val_acc=40.19% best_acc=40.19%
# epoch=019 val_acc=38.56% best_acc=40.19%
# epoch=020 val_acc=38.63% best_acc=40.19%
# epoch=021 val_acc=37.81% best_acc=40.19%
# epoch=022 val_acc=39.81% best_acc=40.19%
# epoch=023 val_acc=39.69% best_acc=40.19%
# epoch=024 val_acc=40.23% best_acc=40.23%
# epoch=025 val_acc=38.97% best_acc=40.23%
# epoch=026 val_acc=39.01% best_acc=40.23%
# epoch=027 val_acc=37.85% best_acc=40.23%
# epoch=028 val_acc=37.62% best_acc=40.23%
# epoch=029 val_acc=39.02% best_acc=40.23%
# epoch=030 val_acc=39.12% best_acc=40.23%
# epoch=031 val_acc=39.58% best_acc=40.23%
# epoch=032 val_acc=38.11% best_acc=40.23%
# epoch=033 val_acc=37.93% best_acc=40.23%
# epoch=034 val_acc=39.52% best_acc=40.23%
# epoch=035 val_acc=37.81% best_acc=40.23%
# epoch=036 val_acc=40.36% best_acc=40.36%
# epoch=037 val_acc=37.98% best_acc=40.36%
# epoch=038 val_acc=38.21% best_acc=40.36%
# epoch=039 val_acc=37.80% best_acc=40.36%
# epoch=040 val_acc=39.56% best_acc=40.36%
# epoch=041 val_acc=38.90% best_acc=40.36%
# epoch=042 val_acc=37.89% best_acc=40.36%
# epoch=043 val_acc=37.78% best_acc=40.36%
# epoch=044 val_acc=39.21% best_acc=40.36%
# epoch=045 val_acc=39.18% best_acc=40.36%
# epoch=046 val_acc=39.76% best_acc=40.36%
# epoch=047 val_acc=39.26% best_acc=40.36%
# epoch=048 val_acc=38.48% best_acc=40.36%
# epoch=049 val_acc=38.17% best_acc=40.36%
# epoch=050 val_acc=39.53% best_acc=40.36%
# epoch=051 val_acc=39.40% best_acc=40.36%
# epoch=052 val_acc=37.85% best_acc=40.36%
# epoch=053 val_acc=39.94% best_acc=40.36%
# epoch=054 val_acc=39.85% best_acc=40.36%
# epoch=055 val_acc=38.78% best_acc=40.36%
# epoch=056 val_acc=38.55% best_acc=40.36%
# epoch=057 val_acc=39.77% best_acc=40.36%
# epoch=058 val_acc=39.00% best_acc=40.36%
# epoch=059 val_acc=38.89% best_acc=40.36%
# epoch=060 val_acc=39.88% best_acc=40.36%
# epoch=061 val_acc=38.92% best_acc=40.36%
# epoch=062 val_acc=38.41% best_acc=40.36%
# epoch=063 val_acc=40.18% best_acc=40.36%
# epoch=064 val_acc=37.92% best_acc=40.36%
# epoch=065 val_acc=39.51% best_acc=40.36%
# epoch=066 val_acc=37.04% best_acc=40.36%
# epoch=067 val_acc=37.37% best_acc=40.36%
# epoch=068 val_acc=39.00% best_acc=40.36%
# epoch=069 val_acc=40.60% best_acc=40.60%
# epoch=070 val_acc=39.28% best_acc=40.60%
# epoch=071 val_acc=39.15% best_acc=40.60%
# epoch=072 val_acc=39.70% best_acc=40.60%
# epoch=073 val_acc=38.31% best_acc=40.60%
# epoch=074 val_acc=39.73% best_acc=40.60%
# epoch=075 val_acc=38.75% best_acc=40.60%
# epoch=076 val_acc=37.98% best_acc=40.60%
# epoch=077 val_acc=36.08% best_acc=40.60%
# epoch=078 val_acc=38.95% best_acc=40.60%
# epoch=079 val_acc=39.53% best_acc=40.60%
# epoch=080 val_acc=39.49% best_acc=40.60%
# epoch=081 val_acc=38.47% best_acc=40.60%
# epoch=082 val_acc=38.45% best_acc=40.60%
# epoch=083 val_acc=39.97% best_acc=40.60%
# epoch=084 val_acc=38.98% best_acc=40.60%
# epoch=085 val_acc=39.39% best_acc=40.60%
# epoch=086 val_acc=37.32% best_acc=40.60%
# epoch=087 val_acc=38.89% best_acc=40.60%
# epoch=088 val_acc=38.60% best_acc=40.60%
# epoch=089 val_acc=36.96% best_acc=40.60%
# epoch=090 val_acc=38.94% best_acc=40.60%
# epoch=091 val_acc=39.09% best_acc=40.60%
# epoch=092 val_acc=37.44% best_acc=40.60%
# epoch=093 val_acc=37.25% best_acc=40.60%
# epoch=094 val_acc=38.47% best_acc=40.60%
# epoch=095 val_acc=39.18% best_acc=40.60%
# epoch=096 val_acc=39.48% best_acc=40.60%
# epoch=097 val_acc=39.34% best_acc=40.60%
# epoch=098 val_acc=39.92% best_acc=40.60%
# epoch=099 val_acc=39.01% best_acc=40.60%
# epoch=100 val_acc=40.07% best_acc=40.60%
# saved classifier: runs/cifar10_pixels_cls.pt

# %%
import torch, glob
print(f'{"Feature":<35}  {"Best Acc":>10}  {"Dim":>8}')
print('-' * 58)
for path in sorted(glob.glob('./runs/cifar10_*_cls.pt')):
    c = torch.load(path, map_location='cpu')
    name = path.split('/')[-1].replace('.pt', '')
    print(f'{name:<35}  {c["best_acc"]:>9.1f}%  {c["in_dim"]:>8}')
# Out:
# Feature                                Best Acc       Dim
# ----------------------------------------------------------
# cifar10_pixels_cls                        40.6%      3072
# cifar10_siren_latent_cls                  45.5%       512
# cifar10_siren_theta_cls                   44.5%     50307

# %% [markdown]
# ---
# ## Section 3 — CIFAR-10 Figure Export

# %%
import os
for arch in ['siren', 'fourier', 'relu']:
    os.system(
        f'python export_recon_examples.py'
        f' --recon-ckpt ./runs/cifar10_{arch}_recon.pt'
        f' --num-images 30'
        f' --out-dir ./runs/figures/cifar10_{arch}'
    )
# Out:
# /home/zihan-gao/miniforge3/envs/dl685/lib/python3.11/site-packages/torchvision/datasets/cifar.py:83: VisibleDeprecationWarning: dtype(): align should be passed as Python or NumPy boolean but got `align=0`. Did you mean to pass a tuple to create a subarray type? (Deprecated NumPy 2.4)
#   entry = pickle.load(f, encoding="latin1")
# /home/zihan-gao/miniforge3/envs/dl685/lib/python3.11/site-packages/torchvision/datasets/cifar.py:83: VisibleDeprecationWarning: dtype(): align should be passed as Python or NumPy boolean but got `align=0`. Did you mean to pass a tuple to create a subarray type? (Deprecated NumPy 2.4)
#   entry = pickle.load(f, encoding="latin1")
# /home/zihan-gao/miniforge3/envs/dl685/lib/python3.11/site-packages/torchvision/datasets/cifar.py:83: VisibleDeprecationWarning: dtype(): align should be passed as Python or NumPy boolean but got `align=0`. Did you mean to pass a tuple to create a subarray type? (Deprecated NumPy 2.4)
#   entry = pickle.load(f, encoding="latin1")

# %%
from PIL import Image
import matplotlib.pyplot as plt

archs = ['siren', 'fourier', 'relu']
n_rows = 5
fig, axes = plt.subplots(n_rows, len(archs) * 2, figsize=(len(archs) * 5, n_rows * 1.6))
for row in range(n_rows):
    for col, arch in enumerate(archs):
        tgt   = Image.open(f'./runs/figures/cifar10_{arch}/{row:04d}_target.png')
        recon = Image.open(f'./runs/figures/cifar10_{arch}/{row:04d}_recon.png')
        axes[row, col*2].imshow(tgt);     axes[row, col*2].axis('off')
        axes[row, col*2+1].imshow(recon); axes[row, col*2+1].axis('off')
        if row == 0:
            axes[0, col*2].set_title(f'{arch}\nTarget')
            axes[0, col*2+1].set_title(f'{arch}\nRecon')
plt.suptitle('CIFAR-10 Reconstructions — Target vs Recon')
plt.tight_layout()
plt.savefig('./runs/figures/cifar10_comparison.png', dpi=150)
plt.show()

# %% [markdown]
# ### CelebA Data Setup
#
# CelebA cannot be auto-downloaded from Google Drive (rate-limited for academic datasets).
# Run the cell below once to fetch it via **Kaggle**:
# 1. Create an account at [kaggle.com](https://www.kaggle.com)
# 2. Go to **Account → Settings → API → Create New Token** — downloads `kaggle.json`
# 3. In a terminal: `mkdir -p ~/.kaggle && cp ~/Downloads/kaggle.json ~/.kaggle/ && chmod 600 ~/.kaggle/kaggle.json`
# 4. Run the cell below
#
# If CelebA is already extracted in `./data/celeba/img_align_celeba/`, the cell will just report the count and skip.

# %%
from IPython.display import display, Javascript
display(Javascript('''
    setInterval(() => {
        document.querySelector("colab-connect-button").click()
    }, 60000)
'''))
print("防掉线已启动")
# Out:
# 防掉线已启动

# %%
import subprocess, shutil, os
from pathlib import Path

# --- 核心修改：全部指向 Colab 本地 SSD ---
TARGET_MIN = 180_000
img_dir = Path('/content/data/celeba/img_align_celeba')
dl_dir = Path('/content/celeba_kaggle_dl')
zip_path = dl_dir / 'celeba-dataset.zip'

# 创建目录
img_dir.mkdir(parents=True, exist_ok=True)
dl_dir.mkdir(parents=True, exist_ok=True)

def count_imgs(path: Path) -> int:
    # 在 Colab 处理 20 万文件时，使用 shell 命令统计比 python 快
    if not path.exists(): return 0
    return int(os.popen(f'find {path} -name "*.jpg" | wc -l').read())

def run_cmd(cmd):
    print('RUN:', ' '.join(str(x) for x in cmd))
    subprocess.run(cmd, check=True)

n_imgs = count_imgs(img_dir)
print(f'Found {n_imgs} CelebA images in {img_dir}')

if n_imgs >= TARGET_MIN:
    print('CelebA already set up.')
else:
    print('CelebA not complete. Start/resume setup...')

    # 1) 安装 kaggle
    run_cmd(['pip', 'install', 'kaggle', '-q'])

    # 确保 kaggle.json 已存在 (手动补丁)
    if not Path('/root/.kaggle/kaggle.json').exists():
        print("⚠️ 请确保已上传 kaggle.json 到 /content/ 或 ~/.kaggle/")

    # 2) 下载压缩包
    if not zip_path.exists():
        run_cmd(['kaggle', 'datasets', 'download', '-d', 'jessicali9530/celeba-dataset', '-p', str(dl_dir)])
    else:
        print(f'Zip already exists: {zip_path}')

    # 3) 解压 (改用 -j 暴力平铺图片，直接解压到目标目录)
    print('Extracting images (junking paths for speed)...')
    # -o: 覆盖, -q: 静默, -j: 丢弃路径结构(平铺), -d: 目标目录
    run_cmd(['unzip', '-o', '-q', '-j', str(zip_path), '*.jpg', '-d', str(img_dir)])

    # 4) 最后的验证
    n_imgs = count_imgs(img_dir)
    print(f'Setup complete: {n_imgs} images')

    # 5) 清理 (可选)
    # shutil.rmtree(dl_dir, ignore_errors=True)
# Out:
# Found 0 CelebA images in /content/data/celeba/img_align_celeba
# CelebA not complete. Start/resume setup...
# RUN: pip install kaggle -q
# RUN: kaggle datasets download -d jessicali9530/celeba-dataset -p /content/celeba_kaggle_dl
# Extracting images (junking paths for speed)...
# RUN: unzip -o -q -j /content/celeba_kaggle_dl/celeba-dataset.zip *.jpg -d /content/data/celeba/img_align_celeba
# Setup complete: 202599 images

# %%
import subprocess, shutil
from pathlib import Path

img_dir = Path('./data/celeba/img_align_celeba')
n_imgs = len(list(img_dir.glob('*.jpg'))) if img_dir.exists() else 0
print(f'Found {n_imgs} CelebA images in {img_dir}')

if n_imgs < 180_000:
    print('Downloading CelebA via Kaggle (~1.4 GB)...')
    subprocess.run(['pip', 'install', 'kaggle', '-q'], check=True)

    dl_dir = Path('./celeba_kaggle_dl')
    dl_dir.mkdir(exist_ok=True)
    subprocess.run(
        ['kaggle', 'datasets', 'download', '-d', 'jessicali9530/celeba-dataset',
         '-p', str(dl_dir), '--unzip'],
        check=True
    )

    # Locate images (Kaggle dataset may be nested one level)
    img_dir.mkdir(parents=True, exist_ok=True)
    for candidate in [
        dl_dir / 'img_align_celeba' / 'img_align_celeba',
        dl_dir / 'img_align_celeba',
        dl_dir / 'celeba' / 'img_align_celeba',
    ]:
        if candidate.exists() and list(candidate.glob('*.jpg')):
            for f in candidate.glob('*.jpg'):
                shutil.move(str(f), str(img_dir / f.name))
            print(f'Moved images from {candidate}')
            break

    shutil.rmtree(dl_dir, ignore_errors=True)
    n_imgs = len(list(img_dir.glob('*.jpg')))
    print(f'Setup complete: {n_imgs} images')
else:
    print('CelebA already set up.')
# Out:
# Found 202599 CelebA images in data/celeba/img_align_celeba
# CelebA already set up.

# %% [markdown]
# ---
# ## Section 4 — CelebA Reconstruction
#
# Same three architectures on CelebA (128×128). Compare quality, stability, and speed.

# %%
# SIREN (~60–90 min)
# !python train_reconstruction.py \
  --dataset celeba --arch siren --image-size 128 \
  --epochs 30 --batch-size 32 --samples-per-image 8192 \
  --hidden-dim 128 --depth 4 --latent-dim 512 \
  --lr 2e-4 --weight-decay 1e-7 \
  --num-workers 8 --amp --eval-batches 30 --out-dir ./runs
# Out:
# Setting up [LPIPS] perceptual loss: trunk [alex], v[0.1], spatial [off]
# /home/zihan-gao/miniforge3/envs/dl685/lib/python3.11/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/zihan-gao/miniforge3/envs/dl685/lib/python3.11/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=AlexNet_Weights.IMAGENET1K_V1`. You can also use `weights=AlexNet_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Loading model from: /home/zihan-gao/miniforge3/envs/dl685/lib/python3.11/site-packages/lpips/weights/v0.1/alex.pth
# device=cuda dataset=celeba arch=siren total_generated_params=50307
# epoch=001 train_mse=0.017668 lr=2.00e-04 time=181.7s val_psnr=18.89 val_ssim=0.5681 val_lpips=0.4509
# saved checkpoint: runs/celeba_siren_recon.pt
# epoch=002 train_mse=0.011091 lr=1.99e-04 time=178.5s val_psnr=19.63 val_ssim=0.5979 val_lpips=0.4158
# saved checkpoint: runs/celeba_siren_recon.pt
# epoch=003 train_mse=0.009740 lr=1.99e-04 time=178.7s val_psnr=20.08 val_ssim=0.6143 val_lpips=0.3997
# saved checkpoint: runs/celeba_siren_recon.pt
# epoch=004 train_mse=0.008934 lr=1.98e-04 time=178.2s val_psnr=20.39 val_ssim=0.6258 val_lpips=0.3879
# saved checkpoint: runs/celeba_siren_recon.pt
# epoch=005 train_mse=0.008426 lr=1.97e-04 time=178.6s val_psnr=20.59 val_ssim=0.6327 val_lpips=0.3762
# saved checkpoint: runs/celeba_siren_recon.pt
# epoch=006 train_mse=0.008026 lr=1.95e-04 time=178.1s val_psnr=20.66 val_ssim=0.6378 val_lpips=0.3713
# saved checkpoint: runs/celeba_siren_recon.pt
# epoch=007 train_mse=0.007720 lr=1.93e-04 time=178.4s val_psnr=20.62 val_ssim=0.6398 val_lpips=0.3637
# epoch=008 train_mse=0.007476 lr=1.91e-04 time=178.3s val_psnr=20.87 val_ssim=0.6503 val_lpips=0.3557
# saved checkpoint: runs/celeba_siren_recon.pt
# epoch=009 train_mse=0.007264 lr=1.89e-04 time=178.2s val_psnr=21.11 val_ssim=0.6544 val_lpips=0.3512
# saved checkpoint: runs/celeba_siren_recon.pt
# epoch=010 train_mse=0.007068 lr=1.87e-04 time=178.3s val_psnr=21.15 val_ssim=0.6562 val_lpips=0.3506
# saved checkpoint: runs/celeba_siren_recon.pt
# epoch=011 train_mse=0.006918 lr=1.84e-04 time=177.9s val_psnr=21.12 val_ssim=0.6588 val_lpips=0.3445
# epoch=012 train_mse=0.006764 lr=1.81e-04 time=178.1s val_psnr=21.27 val_ssim=0.6620 val_lpips=0.3434
# saved checkpoint: runs/celeba_siren_recon.pt
# epoch=013 train_mse=0.006634 lr=1.78e-04 time=177.8s val_psnr=21.27 val_ssim=0.6621 val_lpips=0.3420
# epoch=014 train_mse=0.006524 lr=1.75e-04 time=178.4s val_psnr=21.41 val_ssim=0.6646 val_lpips=0.3379
# saved checkpoint: runs/celeba_siren_recon.pt
# epoch=015 train_mse=0.006412 lr=1.71e-04 time=177.9s val_psnr=21.49 val_ssim=0.6695 val_lpips=0.3415
# saved checkpoint: runs/celeba_siren_recon.pt
# epoch=016 train_mse=0.006323 lr=1.67e-04 time=178.8s val_psnr=21.59 val_ssim=0.6731 val_lpips=0.3342
# saved checkpoint: runs/celeba_siren_recon.pt
# epoch=017 train_mse=0.006236 lr=1.63e-04 time=178.5s val_psnr=21.59 val_ssim=0.6720 val_lpips=0.3386
# saved checkpoint: runs/celeba_siren_recon.pt
# epoch=018 train_mse=0.006148 lr=1.59e-04 time=178.6s val_psnr=21.66 val_ssim=0.6741 val_lpips=0.3315
# saved checkpoint: runs/celeba_siren_recon.pt
# epoch=019 train_mse=0.006074 lr=1.55e-04 time=178.5s val_psnr=21.62 val_ssim=0.6754 val_lpips=0.3338
# epoch=020 train_mse=0.005999 lr=1.50e-04 time=177.8s val_psnr=21.70 val_ssim=0.6781 val_lpips=0.3254
# saved checkpoint: runs/celeba_siren_recon.pt
# epoch=021 train_mse=0.005934 lr=1.46e-04 time=178.5s val_psnr=21.73 val_ssim=0.6784 val_lpips=0.3270
# saved checkpoint: runs/celeba_siren_recon.pt
# epoch=022 train_mse=0.005870 lr=1.41e-04 time=179.1s val_psnr=21.78 val_ssim=0.6804 val_lpips=0.3275
# saved checkpoint: runs/celeba_siren_recon.pt
# epoch=023 train_mse=0.005809 lr=1.36e-04 time=177.1s val_psnr=21.81 val_ssim=0.6834 val_lpips=0.3219
# saved checkpoint: runs/celeba_siren_recon.pt
# epoch=024 train_mse=0.005749 lr=1.32e-04 time=168.6s val_psnr=21.89 val_ssim=0.6839 val_lpips=0.3189
# saved checkpoint: runs/celeba_siren_recon.pt
# epoch=025 train_mse=0.005691 lr=1.27e-04 time=169.5s val_psnr=21.81 val_ssim=0.6812 val_lpips=0.3257
# epoch=026 train_mse=0.005640 lr=1.22e-04 time=174.0s val_psnr=21.90 val_ssim=0.6833 val_lpips=0.3167
# saved checkpoint: runs/celeba_siren_recon.pt

# %%
# Fourier (~60–90 min)
# !python train_reconstruction.py \
  --dataset celeba --arch fourier --image-size 128 \
  --epochs 30 --batch-size 32 --samples-per-image 8192 \
  --hidden-dim 128 --depth 4 --latent-dim 512 \
  --fourier-features 32 --fourier-sigma 10 \
  --lr 2e-4 --weight-decay 1e-7 \
  --num-workers 8 --amp --eval-batches 30 --out-dir ./runs
# Out:
# Setting up [LPIPS] perceptual loss: trunk [alex], v[0.1], spatial [off]
# /home/zihan-gao/miniforge3/envs/dl685/lib/python3.11/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/zihan-gao/miniforge3/envs/dl685/lib/python3.11/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=AlexNet_Weights.IMAGENET1K_V1`. You can also use `weights=AlexNet_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Loading model from: /home/zihan-gao/miniforge3/envs/dl685/lib/python3.11/site-packages/lpips/weights/v0.1/alex.pth
# device=cuda dataset=celeba arch=fourier total_generated_params=58243
# epoch=001 train_mse=0.281268 lr=1.99e-04 time=153.3s val_psnr=4.97 val_ssim=0.2154 val_lpips=0.9473
# saved checkpoint: runs/celeba_fourier_recon.pt
# epoch=002 train_mse=0.321689 lr=1.98e-04 time=150.0s val_psnr=4.97 val_ssim=0.2154 val_lpips=0.9473
# epoch=003 train_mse=0.321682 lr=1.95e-04 time=152.2s val_psnr=4.97 val_ssim=0.2154 val_lpips=0.9473
# saved checkpoint: runs/celeba_fourier_recon.pt
# epoch=004 train_mse=0.059141 lr=1.91e-04 time=154.5s val_psnr=16.13 val_ssim=0.3210 val_lpips=0.7115
# saved checkpoint: runs/celeba_fourier_recon.pt
# epoch=005 train_mse=0.020737 lr=1.87e-04 time=154.7s val_psnr=17.18 val_ssim=0.3668 val_lpips=0.6508
# saved checkpoint: runs/celeba_fourier_recon.pt
# epoch=006 train_mse=0.017215 lr=1.81e-04 time=154.2s val_psnr=17.52 val_ssim=0.3873 val_lpips=0.6237
# saved checkpoint: runs/celeba_fourier_recon.pt
# epoch=007 train_mse=0.015367 lr=1.75e-04 time=153.8s val_psnr=18.17 val_ssim=0.4148 val_lpips=0.5953
# saved checkpoint: runs/celeba_fourier_recon.pt
# epoch=008 train_mse=0.014042 lr=1.67e-04 time=152.9s val_psnr=18.53 val_ssim=0.4304 val_lpips=0.5867
# saved checkpoint: runs/celeba_fourier_recon.pt
# epoch=009 train_mse=0.013061 lr=1.59e-04 time=153.0s val_psnr=18.70 val_ssim=0.4489 val_lpips=0.5632
# saved checkpoint: runs/celeba_fourier_recon.pt
# epoch=010 train_mse=0.012341 lr=1.50e-04 time=153.8s val_psnr=18.97 val_ssim=0.4617 val_lpips=0.5508
# saved checkpoint: runs/celeba_fourier_recon.pt
# epoch=011 train_mse=0.011751 lr=1.41e-04 time=149.4s val_psnr=19.06 val_ssim=0.4735 val_lpips=0.5417
# saved checkpoint: runs/celeba_fourier_recon.pt
# epoch=012 train_mse=0.011268 lr=1.32e-04 time=146.3s val_psnr=19.30 val_ssim=0.4830 val_lpips=0.5260
# saved checkpoint: runs/celeba_fourier_recon.pt
# epoch=013 train_mse=0.010863 lr=1.22e-04 time=145.9s val_psnr=19.45 val_ssim=0.4885 val_lpips=0.5180
# saved checkpoint: runs/celeba_fourier_recon.pt
# epoch=014 train_mse=0.010528 lr=1.11e-04 time=147.5s val_psnr=19.56 val_ssim=0.4974 val_lpips=0.5066
# saved checkpoint: runs/celeba_fourier_recon.pt
# epoch=015 train_mse=0.010238 lr=1.01e-04 time=149.2s val_psnr=19.59 val_ssim=0.5060 val_lpips=0.5003
# saved checkpoint: runs/celeba_fourier_recon.pt
# epoch=016 train_mse=0.009969 lr=9.07e-05 time=150.1s val_psnr=19.71 val_ssim=0.5094 val_lpips=0.4951
# saved checkpoint: runs/celeba_fourier_recon.pt
# epoch=017 train_mse=0.009745 lr=8.04e-05 time=147.7s val_psnr=19.85 val_ssim=0.5141 val_lpips=0.4882
# saved checkpoint: runs/celeba_fourier_recon.pt
# epoch=018 train_mse=0.009549 lr=7.04e-05 time=146.3s val_psnr=19.88 val_ssim=0.5191 val_lpips=0.4873
# saved checkpoint: runs/celeba_fourier_recon.pt
# epoch=019 train_mse=0.009358 lr=6.07e-05 time=144.3s val_psnr=19.95 val_ssim=0.5257 val_lpips=0.4758
# saved checkpoint: runs/celeba_fourier_recon.pt
# epoch=020 train_mse=0.009187 lr=5.15e-05 time=144.6s val_psnr=20.01 val_ssim=0.5302 val_lpips=0.4692
# saved checkpoint: runs/celeba_fourier_recon.pt
# epoch=021 train_mse=0.009044 lr=4.28e-05 time=148.2s val_psnr=20.10 val_ssim=0.5331 val_lpips=0.4679
# saved checkpoint: runs/celeba_fourier_recon.pt
# epoch=022 train_mse=0.008922 lr=3.48e-05 time=147.5s val_psnr=20.16 val_ssim=0.5330 val_lpips=0.4687
# saved checkpoint: runs/celeba_fourier_recon.pt
# epoch=023 train_mse=0.008821 lr=2.74e-05 time=147.0s val_psnr=20.21 val_ssim=0.5374 val_lpips=0.4635
# saved checkpoint: runs/celeba_fourier_recon.pt
# epoch=024 train_mse=0.008729 lr=2.09e-05 time=142.5s val_psnr=20.23 val_ssim=0.5392 val_lpips=0.4625
# saved checkpoint: runs/celeba_fourier_recon.pt
# epoch=025 train_mse=0.008657 lr=1.53e-05 time=141.9s val_psnr=20.26 val_ssim=0.5401 val_lpips=0.4592
# saved checkpoint: runs/celeba_fourier_recon.pt
# epoch=026 train_mse=0.008598 lr=1.06e-05 time=141.3s val_psnr=20.16 val_ssim=0.5412 val_lpips=0.4576
# epoch=027 train_mse=0.008550 lr=6.85e-06 time=141.6s val_psnr=20.30 val_ssim=0.5417 val_lpips=0.4567
# saved checkpoint: runs/celeba_fourier_recon.pt
# epoch=028 train_mse=0.008512 lr=4.16e-06 time=141.1s val_psnr=20.32 val_ssim=0.5427 val_lpips=0.4553
# saved checkpoint: runs/celeba_fourier_recon.pt
# epoch=029 train_mse=0.008486 lr=2.54e-06 time=141.0s val_psnr=20.32 val_ssim=0.5433 val_lpips=0.4554
# saved checkpoint: runs/celeba_fourier_recon.pt
# epoch=030 train_mse=0.008470 lr=2.00e-06 time=142.3s val_psnr=20.30 val_ssim=0.5443 val_lpips=0.4545

# %%
# ReLU (~60–90 min)
# !python train_reconstruction.py \
  --dataset celeba --arch relu --image-size 128 \
  --epochs 30 --batch-size 32 --samples-per-image 8192 \
  --hidden-dim 128 --depth 4 --latent-dim 512 \
  --lr 2e-4 --weight-decay 1e-7 \
  --num-workers 8 --amp --eval-batches 30 --out-dir ./runs
# Out:
# Setting up [LPIPS] perceptual loss: trunk [alex], v[0.1], spatial [off]
# /home/zihan-gao/miniforge3/envs/dl685/lib/python3.11/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/zihan-gao/miniforge3/envs/dl685/lib/python3.11/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=AlexNet_Weights.IMAGENET1K_V1`. You can also use `weights=AlexNet_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Loading model from: /home/zihan-gao/miniforge3/envs/dl685/lib/python3.11/site-packages/lpips/weights/v0.1/alex.pth
# device=cuda dataset=celeba arch=relu total_generated_params=50307
# epoch=001 train_mse=0.275325 lr=1.99e-04 time=142.9s val_psnr=5.51 val_ssim=0.0204 val_lpips=0.8445
# saved checkpoint: runs/celeba_relu_recon.pt
# epoch=002 train_mse=0.168105 lr=1.98e-04 time=140.4s val_psnr=17.33 val_ssim=0.5076 val_lpips=0.4854
# saved checkpoint: runs/celeba_relu_recon.pt
# epoch=003 train_mse=0.015448 lr=1.95e-04 time=139.6s val_psnr=18.42 val_ssim=0.5466 val_lpips=0.4077
# saved checkpoint: runs/celeba_relu_recon.pt
# epoch=004 train_mse=0.013014 lr=1.91e-04 time=142.8s val_psnr=18.95 val_ssim=0.5613 val_lpips=0.3861
# saved checkpoint: runs/celeba_relu_recon.pt
# epoch=005 train_mse=0.011935 lr=1.87e-04 time=137.1s val_psnr=19.21 val_ssim=0.5709 val_lpips=0.3731
# saved checkpoint: runs/celeba_relu_recon.pt
# epoch=006 train_mse=0.011211 lr=1.81e-04 time=134.6s val_psnr=19.42 val_ssim=0.5776 val_lpips=0.3633
# saved checkpoint: runs/celeba_relu_recon.pt
# epoch=007 train_mse=0.010669 lr=1.75e-04 time=134.1s val_psnr=19.56 val_ssim=0.5847 val_lpips=0.3580
# saved checkpoint: runs/celeba_relu_recon.pt
# epoch=008 train_mse=0.010284 lr=1.67e-04 time=135.0s val_psnr=19.68 val_ssim=0.5875 val_lpips=0.3515
# saved checkpoint: runs/celeba_relu_recon.pt
# epoch=009 train_mse=0.009959 lr=1.59e-04 time=132.9s val_psnr=19.80 val_ssim=0.5941 val_lpips=0.3440
# saved checkpoint: runs/celeba_relu_recon.pt
# epoch=010 train_mse=0.009707 lr=1.50e-04 time=130.6s val_psnr=19.85 val_ssim=0.5978 val_lpips=0.3444
# saved checkpoint: runs/celeba_relu_recon.pt
# epoch=011 train_mse=0.009485 lr=1.41e-04 time=133.6s val_psnr=19.99 val_ssim=0.5983 val_lpips=0.3367
# saved checkpoint: runs/celeba_relu_recon.pt
# epoch=012 train_mse=0.009279 lr=1.32e-04 time=131.5s val_psnr=20.02 val_ssim=0.6006 val_lpips=0.3370
# saved checkpoint: runs/celeba_relu_recon.pt
# epoch=013 train_mse=0.009090 lr=1.22e-04 time=130.7s val_psnr=20.04 val_ssim=0.6020 val_lpips=0.3316
# saved checkpoint: runs/celeba_relu_recon.pt
# epoch=014 train_mse=0.008946 lr=1.11e-04 time=130.0s val_psnr=20.20 val_ssim=0.6067 val_lpips=0.3264
# saved checkpoint: runs/celeba_relu_recon.pt
# epoch=015 train_mse=0.008801 lr=1.01e-04 time=131.0s val_psnr=20.28 val_ssim=0.6102 val_lpips=0.3220
# saved checkpoint: runs/celeba_relu_recon.pt
# epoch=016 train_mse=0.008682 lr=9.07e-05 time=128.4s val_psnr=20.27 val_ssim=0.6091 val_lpips=0.3231
# epoch=017 train_mse=0.008554 lr=8.04e-05 time=131.8s val_psnr=20.27 val_ssim=0.6127 val_lpips=0.3192
# epoch=018 train_mse=0.008452 lr=7.04e-05 time=131.7s val_psnr=20.38 val_ssim=0.6140 val_lpips=0.3180
# saved checkpoint: runs/celeba_relu_recon.pt
# epoch=019 train_mse=0.008355 lr=6.07e-05 time=134.3s val_psnr=20.44 val_ssim=0.6148 val_lpips=0.3168
# saved checkpoint: runs/celeba_relu_recon.pt
# epoch=020 train_mse=0.008270 lr=5.15e-05 time=134.1s val_psnr=20.43 val_ssim=0.6143 val_lpips=0.3131
# epoch=021 train_mse=0.008190 lr=4.28e-05 time=128.9s val_psnr=20.51 val_ssim=0.6172 val_lpips=0.3106
# saved checkpoint: runs/celeba_relu_recon.pt
# epoch=022 train_mse=0.008116 lr=3.48e-05 time=127.3s val_psnr=20.52 val_ssim=0.6172 val_lpips=0.3100
# saved checkpoint: runs/celeba_relu_recon.pt
# epoch=023 train_mse=0.008057 lr=2.74e-05 time=127.8s val_psnr=20.53 val_ssim=0.6187 val_lpips=0.3093
# saved checkpoint: runs/celeba_relu_recon.pt
# epoch=024 train_mse=0.008001 lr=2.09e-05 time=127.3s val_psnr=20.57 val_ssim=0.6191 val_lpips=0.3075
# saved checkpoint: runs/celeba_relu_recon.pt
# epoch=025 train_mse=0.007952 lr=1.53e-05 time=127.6s val_psnr=20.54 val_ssim=0.6202 val_lpips=0.3062
# epoch=026 train_mse=0.007912 lr=1.06e-05 time=127.4s val_psnr=20.60 val_ssim=0.6209 val_lpips=0.3053
# saved checkpoint: runs/celeba_relu_recon.pt
# epoch=027 train_mse=0.007878 lr=6.85e-06 time=127.3s val_psnr=20.61 val_ssim=0.6206 val_lpips=0.3051
# saved checkpoint: runs/celeba_relu_recon.pt
# epoch=028 train_mse=0.007854 lr=4.16e-06 time=127.3s val_psnr=20.63 val_ssim=0.6207 val_lpips=0.3041
# saved checkpoint: runs/celeba_relu_recon.pt
# epoch=029 train_mse=0.007836 lr=2.54e-06 time=127.4s val_psnr=20.62 val_ssim=0.6210 val_lpips=0.3042
# epoch=030 train_mse=0.007824 lr=2.00e-06 time=127.8s val_psnr=20.64 val_ssim=0.6212 val_lpips=0.3040
# saved checkpoint: runs/celeba_relu_recon.pt

# %% [markdown]
# ---
# ## Section 5 — Super-Resolution
#
# Protocol: train on **64×64** CelebA, query coordinate network at **256×256** (4× SR).
# Checkpoints saved as `celeba_<arch>_superres64to256_recon.pt` (separate from Section 4).

# %%
# SIREN super-resolution
# !python train_reconstruction.py \
  --dataset celeba --arch siren --image-size 128 \
  --train-lowres 64 --superres-eval-size 256 \
  --epochs 30 --batch-size 32 --samples-per-image 8192 \
  --hidden-dim 128 --depth 4 --latent-dim 512 \
  --lr 2e-4 --weight-decay 1e-7 \
  --num-workers 8 --amp --eval-batches 30 --out-dir ./runs
# Out:
# Setting up [LPIPS] perceptual loss: trunk [alex], v[0.1], spatial [off]
# /home/zihan-gao/miniforge3/envs/dl685/lib/python3.11/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/zihan-gao/miniforge3/envs/dl685/lib/python3.11/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=AlexNet_Weights.IMAGENET1K_V1`. You can also use `weights=AlexNet_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Loading model from: /home/zihan-gao/miniforge3/envs/dl685/lib/python3.11/site-packages/lpips/weights/v0.1/alex.pth
# device=cuda dataset=celeba arch=siren total_generated_params=50307
# epoch=001 train_mse=0.014702 lr=1.99e-04 time=164.1s val_psnr=19.63 val_ssim=0.6777 val_lpips=0.4860
# saved checkpoint: runs/celeba_siren_superres64to256_recon.pt
# epoch=002 train_mse=0.008005 lr=1.98e-04 time=165.7s val_psnr=20.51 val_ssim=0.6972 val_lpips=0.4516
# saved checkpoint: runs/celeba_siren_superres64to256_recon.pt
# epoch=003 train_mse=0.006529 lr=1.95e-04 time=163.9s val_psnr=21.21 val_ssim=0.7127 val_lpips=0.4266
# saved checkpoint: runs/celeba_siren_superres64to256_recon.pt
# epoch=004 train_mse=0.005650 lr=1.91e-04 time=164.1s val_psnr=21.69 val_ssim=0.7233 val_lpips=0.4162
# saved checkpoint: runs/celeba_siren_superres64to256_recon.pt
# epoch=005 train_mse=0.005080 lr=1.87e-04 time=164.7s val_psnr=21.87 val_ssim=0.7302 val_lpips=0.4034
# saved checkpoint: runs/celeba_siren_superres64to256_recon.pt
# epoch=006 train_mse=0.004674 lr=1.81e-04 time=168.6s val_psnr=22.13 val_ssim=0.7340 val_lpips=0.3986
# saved checkpoint: runs/celeba_siren_superres64to256_recon.pt
# epoch=007 train_mse=0.004357 lr=1.75e-04 time=168.5s val_psnr=22.43 val_ssim=0.7420 val_lpips=0.3880
# saved checkpoint: runs/celeba_siren_superres64to256_recon.pt
# epoch=008 train_mse=0.004097 lr=1.67e-04 time=167.4s val_psnr=22.49 val_ssim=0.7453 val_lpips=0.3843
# saved checkpoint: runs/celeba_siren_superres64to256_recon.pt
# epoch=009 train_mse=0.003891 lr=1.59e-04 time=166.8s val_psnr=22.70 val_ssim=0.7476 val_lpips=0.3769
# saved checkpoint: runs/celeba_siren_superres64to256_recon.pt
# epoch=010 train_mse=0.003710 lr=1.50e-04 time=167.7s val_psnr=22.78 val_ssim=0.7504 val_lpips=0.3793
# saved checkpoint: runs/celeba_siren_superres64to256_recon.pt
# epoch=011 train_mse=0.003550 lr=1.41e-04 time=168.4s val_psnr=22.98 val_ssim=0.7532 val_lpips=0.3683
# saved checkpoint: runs/celeba_siren_superres64to256_recon.pt
# epoch=012 train_mse=0.003412 lr=1.32e-04 time=168.7s val_psnr=23.14 val_ssim=0.7545 val_lpips=0.3699
# saved checkpoint: runs/celeba_siren_superres64to256_recon.pt
# epoch=013 train_mse=0.003285 lr=1.22e-04 time=168.5s val_psnr=23.11 val_ssim=0.7595 val_lpips=0.3638
# epoch=014 train_mse=0.003173 lr=1.11e-04 time=168.9s val_psnr=23.39 val_ssim=0.7603 val_lpips=0.3630
# saved checkpoint: runs/celeba_siren_superres64to256_recon.pt
# epoch=015 train_mse=0.003079 lr=1.01e-04 time=169.7s val_psnr=22.84 val_ssim=0.7594 val_lpips=0.3607
# epoch=016 train_mse=0.002996 lr=9.07e-05 time=169.0s val_psnr=23.35 val_ssim=0.7642 val_lpips=0.3572
# epoch=017 train_mse=0.002907 lr=8.04e-05 time=167.6s val_psnr=23.36 val_ssim=0.7616 val_lpips=0.3570
# epoch=018 train_mse=0.002830 lr=7.04e-05 time=167.6s val_psnr=23.56 val_ssim=0.7670 val_lpips=0.3527
# saved checkpoint: runs/celeba_siren_superres64to256_recon.pt
# epoch=019 train_mse=0.002757 lr=6.07e-05 time=168.7s val_psnr=23.71 val_ssim=0.7698 val_lpips=0.3509
# saved checkpoint: runs/celeba_siren_superres64to256_recon.pt
# epoch=020 train_mse=0.002692 lr=5.15e-05 time=167.4s val_psnr=23.80 val_ssim=0.7709 val_lpips=0.3498
# saved checkpoint: runs/celeba_siren_superres64to256_recon.pt
# epoch=021 train_mse=0.002631 lr=4.28e-05 time=169.3s val_psnr=23.74 val_ssim=0.7713 val_lpips=0.3490
# epoch=022 train_mse=0.002577 lr=3.48e-05 time=168.7s val_psnr=23.91 val_ssim=0.7728 val_lpips=0.3462
# saved checkpoint: runs/celeba_siren_superres64to256_recon.pt
# epoch=023 train_mse=0.002525 lr=2.74e-05 time=168.2s val_psnr=23.95 val_ssim=0.7731 val_lpips=0.3463
# saved checkpoint: runs/celeba_siren_superres64to256_recon.pt
# epoch=024 train_mse=0.002479 lr=2.09e-05 time=163.8s val_psnr=23.98 val_ssim=0.7754 val_lpips=0.3440
# saved checkpoint: runs/celeba_siren_superres64to256_recon.pt
# epoch=025 train_mse=0.002441 lr=1.53e-05 time=165.3s val_psnr=24.02 val_ssim=0.7748 val_lpips=0.3443
# saved checkpoint: runs/celeba_siren_superres64to256_recon.pt
# epoch=026 train_mse=0.002404 lr=1.06e-05 time=161.8s val_psnr=24.04 val_ssim=0.7759 val_lpips=0.3438
# saved checkpoint: runs/celeba_siren_superres64to256_recon.pt
# epoch=027 train_mse=0.002376 lr=6.85e-06 time=163.9s val_psnr=24.11 val_ssim=0.7761 val_lpips=0.3438
# saved checkpoint: runs/celeba_siren_superres64to256_recon.pt
# epoch=028 train_mse=0.002353 lr=4.16e-06 time=167.5s val_psnr=24.13 val_ssim=0.7758 val_lpips=0.3430
# saved checkpoint: runs/celeba_siren_superres64to256_recon.pt
# epoch=029 train_mse=0.002335 lr=2.54e-06 time=168.0s val_psnr=24.14 val_ssim=0.7768 val_lpips=0.3425
# saved checkpoint: runs/celeba_siren_superres64to256_recon.pt
# epoch=030 train_mse=0.002324 lr=2.00e-06 time=168.5s val_psnr=24.14 val_ssim=0.7766 val_lpips=0.3427

# %%
# Fourier super-resolution
# !python train_reconstruction.py \
  --dataset celeba --arch fourier --image-size 128 \
  --train-lowres 64 --superres-eval-size 256 \
  --epochs 30 --batch-size 32 --samples-per-image 8192 \
  --hidden-dim 128 --depth 4 --latent-dim 512 \
  --fourier-features 32 --fourier-sigma 10 \
  --lr 2e-4 --weight-decay 1e-7 \
  --num-workers 8 --amp --eval-batches 30 --out-dir ./runs

# %%
# Fourier super-resolution
# !python train_reconstruction.py \
  --dataset celeba --arch fourier --image-size 128 \
  --train-lowres 64 --superres-eval-size 256 \
  --epochs 30 --batch-size 32 --samples-per-image 8192 \
  --hidden-dim 128 --depth 4 --latent-dim 512 \
  --fourier-features 32 --fourier-sigma 10 \
  --lr 2e-4 --weight-decay 1e-7 \
  --num-workers 8 --amp --eval-batches 30 --out-dir ./runs \
  --data-root /content/data
# Out:
# Setting up [LPIPS] perceptual loss: trunk [alex], v[0.1], spatial [off]
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=AlexNet_Weights.IMAGENET1K_V1`. You can also use `weights=AlexNet_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Loading model from: /usr/local/lib/python3.12/dist-packages/lpips/weights/v0.1/alex.pth
# device=cuda dataset=celeba arch=fourier total_generated_params=58243
# epoch=001 train_mse=0.014013 lr=1.99e-04 time=63.6s val_psnr=20.23 val_ssim=0.6687 val_lpips=0.4773
# saved checkpoint: runs/celeba_fourier_superres64to256_recon.pt
# epoch=002 train_mse=0.006684 lr=1.98e-04 time=60.9s val_psnr=21.13 val_ssim=0.7023 val_lpips=0.4134
# saved checkpoint: runs/celeba_fourier_superres64to256_recon.pt
# epoch=003 train_mse=0.005294 lr=1.95e-04 time=61.0s val_psnr=22.01 val_ssim=0.7190 val_lpips=0.3844
# saved checkpoint: runs/celeba_fourier_superres64to256_recon.pt
# epoch=004 train_mse=0.004564 lr=1.91e-04 time=61.3s val_psnr=22.24 val_ssim=0.7289 val_lpips=0.3689
# saved checkpoint: runs/celeba_fourier_superres64to256_recon.pt
# epoch=005 train_mse=0.004119 lr=1.87e-04 time=61.2s val_psnr=22.53 val_ssim=0.7308 val_lpips=0.3598
# saved checkpoint: runs/celeba_fourier_superres64to256_recon.pt
# epoch=006 train_mse=0.003785 lr=1.81e-04 time=61.3s val_psnr=22.61 val_ssim=0.7442 val_lpips=0.3514
# saved checkpoint: runs/celeba_fourier_superres64to256_recon.pt
# epoch=007 train_mse=0.003559 lr=1.75e-04 time=62.7s val_psnr=23.05 val_ssim=0.7491 val_lpips=0.3411
# saved checkpoint: runs/celeba_fourier_superres64to256_recon.pt
# epoch=008 train_mse=0.003372 lr=1.67e-04 time=62.4s val_psnr=23.18 val_ssim=0.7492 val_lpips=0.3379
# saved checkpoint: runs/celeba_fourier_superres64to256_recon.pt
# epoch=009 train_mse=0.003221 lr=1.59e-04 time=62.2s val_psnr=23.27 val_ssim=0.7533 val_lpips=0.3320
# saved checkpoint: runs/celeba_fourier_superres64to256_recon.pt
# epoch=010 train_mse=0.003079 lr=1.50e-04 time=62.0s val_psnr=23.53 val_ssim=0.7562 val_lpips=0.3294
# saved checkpoint: runs/celeba_fourier_superres64to256_recon.pt
# epoch=011 train_mse=0.002970 lr=1.41e-04 time=61.2s val_psnr=23.55 val_ssim=0.7589 val_lpips=0.3258
# saved checkpoint: runs/celeba_fourier_superres64to256_recon.pt
# epoch=012 train_mse=0.002870 lr=1.32e-04 time=61.0s val_psnr=23.48 val_ssim=0.7581 val_lpips=0.3232
# epoch=013 train_mse=0.002787 lr=1.22e-04 time=61.2s val_psnr=23.73 val_ssim=0.7631 val_lpips=0.3205
# saved checkpoint: runs/celeba_fourier_superres64to256_recon.pt
# epoch=014 train_mse=0.002694 lr=1.11e-04 time=61.5s val_psnr=23.71 val_ssim=0.7658 val_lpips=0.3171
# epoch=015 train_mse=0.002619 lr=1.01e-04 time=61.8s val_psnr=23.88 val_ssim=0.7662 val_lpips=0.3158
# saved checkpoint: runs/celeba_fourier_superres64to256_recon.pt
# epoch=016 train_mse=0.002555 lr=9.07e-05 time=61.6s val_psnr=23.83 val_ssim=0.7678 val_lpips=0.3149
# epoch=017 train_mse=0.002486 lr=8.04e-05 time=61.8s val_psnr=24.11 val_ssim=0.7709 val_lpips=0.3124
# saved checkpoint: runs/celeba_fourier_superres64to256_recon.pt
# epoch=018 train_mse=0.002428 lr=7.04e-05 time=62.1s val_psnr=24.05 val_ssim=0.7700 val_lpips=0.3105
# epoch=019 train_mse=0.002363 lr=6.07e-05 time=61.1s val_psnr=24.01 val_ssim=0.7715 val_lpips=0.3110
# epoch=020 train_mse=0.002313 lr=5.15e-05 time=61.1s val_psnr=24.17 val_ssim=0.7727 val_lpips=0.3070
# saved checkpoint: runs/celeba_fourier_superres64to256_recon.pt
# epoch=021 train_mse=0.002263 lr=4.28e-05 time=61.3s val_psnr=24.07 val_ssim=0.7751 val_lpips=0.3077
# epoch=022 train_mse=0.002219 lr=3.48e-05 time=61.6s val_psnr=24.26 val_ssim=0.7765 val_lpips=0.3062
# saved checkpoint: runs/celeba_fourier_superres64to256_recon.pt
# epoch=023 train_mse=0.002182 lr=2.74e-05 time=61.4s val_psnr=24.33 val_ssim=0.7772 val_lpips=0.3061
# saved checkpoint: runs/celeba_fourier_superres64to256_recon.pt
# epoch=024 train_mse=0.002144 lr=2.09e-05 time=61.1s val_psnr=24.41 val_ssim=0.7773 val_lpips=0.3049
# saved checkpoint: runs/celeba_fourier_superres64to256_recon.pt
# epoch=025 train_mse=0.002111 lr=1.53e-05 time=61.0s val_psnr=24.42 val_ssim=0.7792 val_lpips=0.3037
# saved checkpoint: runs/celeba_fourier_superres64to256_recon.pt
# epoch=026 train_mse=0.002081 lr=1.06e-05 time=60.7s val_psnr=24.49 val_ssim=0.7781 val_lpips=0.3046
# saved checkpoint: runs/celeba_fourier_superres64to256_recon.pt
# epoch=027 train_mse=0.002058 lr=6.85e-06 time=61.2s val_psnr=24.51 val_ssim=0.7793 val_lpips=0.3045
# saved checkpoint: runs/celeba_fourier_superres64to256_recon.pt
# epoch=028 train_mse=0.002040 lr=4.16e-06 time=61.5s val_psnr=24.52 val_ssim=0.7799 val_lpips=0.3044
# saved checkpoint: runs/celeba_fourier_superres64to256_recon.pt
# epoch=029 train_mse=0.002026 lr=2.54e-06 time=61.1s val_psnr=24.54 val_ssim=0.7791 val_lpips=0.3045
# saved checkpoint: runs/celeba_fourier_superres64to256_recon.pt
# epoch=030 train_mse=0.002017 lr=2.00e-06 time=60.8s val_psnr=24.55 val_ssim=0.7795 val_lpips=0.3041
# saved checkpoint: runs/celeba_fourier_superres64to256_recon.pt

# %%
# ReLU super-resolution
# !python train_reconstruction.py \
  --dataset celeba --arch relu --image-size 128 \
  --train-lowres 64 --superres-eval-size 256 \
  --epochs 30 --batch-size 32 --samples-per-image 8192 \
  --hidden-dim 128 --depth 4 --latent-dim 512 \
  --lr 2e-4 --weight-decay 1e-7 \
  --num-workers 8 --amp --eval-batches 30 --out-dir ./runs

# %%
# !python train_reconstruction.py \
  --dataset celeba --arch relu --image-size 128 \
  --train-lowres 64 --superres-eval-size 256 \
  --epochs 30 --batch-size 32 --samples-per-image 8192 \
  --hidden-dim 128 --depth 4 --latent-dim 512 \
  --lr 2e-4 --weight-decay 1e-7 \
  --num-workers 8 --amp --eval-batches 30 --out-dir ./runs \
  --data-root /content/data
# Out:
# Setting up [LPIPS] perceptual loss: trunk [alex], v[0.1], spatial [off]
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=AlexNet_Weights.IMAGENET1K_V1`. You can also use `weights=AlexNet_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/alexnet-owt-7be5be79.pth" to /root/.cache/torch/hub/checkpoints/alexnet-owt-7be5be79.pth
# 100% 233M/233M [00:01<00:00, 213MB/s]
# Loading model from: /usr/local/lib/python3.12/dist-packages/lpips/weights/v0.1/alex.pth
# device=cuda dataset=celeba arch=relu total_generated_params=50307
# epoch=001 train_mse=0.014249 lr=1.99e-04 time=62.9s val_psnr=19.68 val_ssim=0.6819 val_lpips=0.4359
# saved checkpoint: runs/celeba_relu_superres64to256_recon.pt
# epoch=002 train_mse=0.007910 lr=1.98e-04 time=59.4s val_psnr=20.67 val_ssim=0.6998 val_lpips=0.4054
# saved checkpoint: runs/celeba_relu_superres64to256_recon.pt
# epoch=003 train_mse=0.006555 lr=1.95e-04 time=59.1s val_psnr=21.05 val_ssim=0.7146 val_lpips=0.3750
# saved checkpoint: runs/celeba_relu_superres64to256_recon.pt
# epoch=004 train_mse=0.005805 lr=1.91e-04 time=59.7s val_psnr=21.43 val_ssim=0.7189 val_lpips=0.3591
# saved checkpoint: runs/celeba_relu_superres64to256_recon.pt
# epoch=005 train_mse=0.005308 lr=1.87e-04 time=59.4s val_psnr=21.69 val_ssim=0.7234 val_lpips=0.3538
# saved checkpoint: runs/celeba_relu_superres64to256_recon.pt
# epoch=006 train_mse=0.004960 lr=1.81e-04 time=58.9s val_psnr=22.08 val_ssim=0.7317 val_lpips=0.3423
# saved checkpoint: runs/celeba_relu_superres64to256_recon.pt
# epoch=007 train_mse=0.004653 lr=1.75e-04 time=59.5s val_psnr=22.19 val_ssim=0.7342 val_lpips=0.3387
# saved checkpoint: runs/celeba_relu_superres64to256_recon.pt
# epoch=008 train_mse=0.004406 lr=1.67e-04 time=59.5s val_psnr=22.25 val_ssim=0.7379 val_lpips=0.3329
# saved checkpoint: runs/celeba_relu_superres64to256_recon.pt
# epoch=009 train_mse=0.004204 lr=1.59e-04 time=59.1s val_psnr=22.49 val_ssim=0.7416 val_lpips=0.3272
# saved checkpoint: runs/celeba_relu_superres64to256_recon.pt
# epoch=010 train_mse=0.004027 lr=1.50e-04 time=59.7s val_psnr=22.60 val_ssim=0.7427 val_lpips=0.3219
# saved checkpoint: runs/celeba_relu_superres64to256_recon.pt
# epoch=011 train_mse=0.003878 lr=1.41e-04 time=59.5s val_psnr=22.66 val_ssim=0.7434 val_lpips=0.3208
# saved checkpoint: runs/celeba_relu_superres64to256_recon.pt
# epoch=012 train_mse=0.003739 lr=1.32e-04 time=59.7s val_psnr=22.62 val_ssim=0.7472 val_lpips=0.3193
# epoch=013 train_mse=0.003620 lr=1.22e-04 time=58.9s val_psnr=22.75 val_ssim=0.7481 val_lpips=0.3147
# saved checkpoint: runs/celeba_relu_superres64to256_recon.pt
# epoch=014 train_mse=0.003511 lr=1.11e-04 time=59.6s val_psnr=22.93 val_ssim=0.7504 val_lpips=0.3099
# saved checkpoint: runs/celeba_relu_superres64to256_recon.pt
# epoch=015 train_mse=0.003407 lr=1.01e-04 time=58.9s val_psnr=23.11 val_ssim=0.7529 val_lpips=0.3064
# saved checkpoint: runs/celeba_relu_superres64to256_recon.pt
# epoch=016 train_mse=0.003314 lr=9.07e-05 time=60.4s val_psnr=23.20 val_ssim=0.7537 val_lpips=0.3049
# saved checkpoint: runs/celeba_relu_superres64to256_recon.pt
# epoch=017 train_mse=0.003226 lr=8.04e-05 time=59.5s val_psnr=23.22 val_ssim=0.7571 val_lpips=0.3035
# saved checkpoint: runs/celeba_relu_superres64to256_recon.pt
# epoch=018 train_mse=0.003148 lr=7.04e-05 time=59.8s val_psnr=23.30 val_ssim=0.7558 val_lpips=0.3032
# saved checkpoint: runs/celeba_relu_superres64to256_recon.pt
# epoch=019 train_mse=0.003075 lr=6.07e-05 time=59.5s val_psnr=23.40 val_ssim=0.7574 val_lpips=0.3004
# saved checkpoint: runs/celeba_relu_superres64to256_recon.pt
# epoch=020 train_mse=0.003008 lr=5.15e-05 time=60.5s val_psnr=23.46 val_ssim=0.7592 val_lpips=0.2987
# saved checkpoint: runs/celeba_relu_superres64to256_recon.pt
# epoch=021 train_mse=0.002947 lr=4.28e-05 time=59.4s val_psnr=23.56 val_ssim=0.7612 val_lpips=0.2963
# saved checkpoint: runs/celeba_relu_superres64to256_recon.pt
# epoch=022 train_mse=0.002893 lr=3.48e-05 time=59.6s val_psnr=23.48 val_ssim=0.7601 val_lpips=0.2966
# epoch=023 train_mse=0.002840 lr=2.74e-05 time=59.4s val_psnr=23.60 val_ssim=0.7603 val_lpips=0.2948
# saved checkpoint: runs/celeba_relu_superres64to256_recon.pt
# epoch=024 train_mse=0.002799 lr=2.09e-05 time=59.1s val_psnr=23.64 val_ssim=0.7623 val_lpips=0.2937
# saved checkpoint: runs/celeba_relu_superres64to256_recon.pt
# epoch=025 train_mse=0.002758 lr=1.53e-05 time=59.3s val_psnr=23.59 val_ssim=0.7627 val_lpips=0.2935
# epoch=026 train_mse=0.002724 lr=1.06e-05 time=59.4s val_psnr=23.66 val_ssim=0.7622 val_lpips=0.2933
# saved checkpoint: runs/celeba_relu_superres64to256_recon.pt
# epoch=027 train_mse=0.002697 lr=6.85e-06 time=59.9s val_psnr=23.67 val_ssim=0.7624 val_lpips=0.2921
# saved checkpoint: runs/celeba_relu_superres64to256_recon.pt
# epoch=028 train_mse=0.002674 lr=4.16e-06 time=59.4s val_psnr=23.69 val_ssim=0.7632 val_lpips=0.2917
# saved checkpoint: runs/celeba_relu_superres64to256_recon.pt
# epoch=029 train_mse=0.002657 lr=2.54e-06 time=59.2s val_psnr=23.70 val_ssim=0.7637 val_lpips=0.2917
# saved checkpoint: runs/celeba_relu_superres64to256_recon.pt
# epoch=030 train_mse=0.002647 lr=2.00e-06 time=59.3s val_psnr=23.73 val_ssim=0.7637 val_lpips=0.2913
# saved checkpoint: runs/celeba_relu_superres64to256_recon.pt

# %% [markdown]
# ---
# ## Section 6 — Figure Export

# %%
import os
for arch in ['siren', 'fourier', 'relu']:
    os.system(
        f'python export_recon_examples.py'
        f' --recon-ckpt ./runs/celeba_{arch}_recon.pt'
        f' --num-images 20'
        f' --out-dir ./runs/figures/celeba_{arch}'
    )

# %%
import os
for arch in ['siren', 'fourier', 'relu']:
    os.system(
        f'python export_recon_examples.py'
        f' --recon-ckpt ./runs/celeba_{arch}_superres64to256_recon.pt'
        f' --train-lowres 64 --output-size 256'
        f' --num-images 10'
        f' --out-dir ./runs/figures/celeba_{arch}_superres256'
    )

# %%
import os
for arch in ['fourier', 'relu']:
    os.system(
        f'python export_recon_examples.py'
        f' --recon-ckpt ./runs/celeba_{arch}_superres64to256_recon.pt'
        f' --train-lowres 64 --output-size 256'
        f' --num-images 10'
        f' --out-dir ./runs/figures/celeba_{arch}_superres256'
        f' --data-root /content/data'
    )

# %% [markdown]
# ---
# ## Section 7 — Full Results Summary

# %%
import json, glob

print(f'{"Model":<42}  {"Best PSNR":>9}  {"SSIM":>8}  {"LPIPS":>8}  {"Epoch":>6}')
print('-' * 80)
for path in sorted(glob.glob('./runs/*_recon_metrics.jsonl')):
    rows = [json.loads(l) for l in open(path)]
    best = max(rows, key=lambda r: r.get('psnr', -1))
    name = path.split('/')[-1].replace('_recon_metrics.jsonl', '')
    lpips = f"{best['lpips']:.4f}" if 'lpips' in best else '   N/A'
    print(f'{name:<42}  {best["psnr"]:>9.2f}  {best["ssim"]:>8.4f}  {lpips:>8}  {best["epoch"]:>6}')
# Out:
# Model                                       Best PSNR      SSIM     LPIPS   Epoch
# --------------------------------------------------------------------------------
# celeba_fourier                                  20.32    0.5433    0.4554      29
# celeba_fourier_superres64to256                  24.55    0.7795    0.3041      30
# celeba_relu                                     20.64    0.6212    0.3040      30
# celeba_relu_superres64to256                     23.73    0.7637    0.2913      30
# celeba_siren                                    21.90    0.6833    0.3167      26
# celeba_siren_superres64to256                    24.14    0.7768    0.3425      29
# cifar10_fourier                                 26.49    0.9207    0.0270     118
# cifar10_relu                                    25.67    0.9044    0.0450     120
# cifar10_siren                                   26.48    0.9202    0.0345     116

# %%
import torch, glob

print(f'{"Classifier":<35}  {"Best Acc":>10}  {"Feature":>10}  {"Dim":>8}')
print('-' * 68)
for path in sorted(glob.glob('./runs/*_cls.pt')):
    c = torch.load(path, map_location='cpu')
    name = path.split('/')[-1].replace('.pt', '')
    print(f'{name:<35}  {c["best_acc"]:>9.1f}%  {c["feature_type"]:>10}  {c["in_dim"]:>8}')
# Out:
# Classifier                             Best Acc     Feature       Dim
# --------------------------------------------------------------------
# cifar10_pixels_cls                        40.6%      pixels      3072
# cifar10_siren_latent_cls                  45.5%      latent       512
# cifar10_siren_theta_cls                   44.5%       theta     50307

# %%
import json, glob

print(f'{"Model":<42}  {"Avg sec/epoch":>14}  {"Epochs":>7}')
print('-' * 68)
for path in sorted(glob.glob('./runs/*_recon_metrics.jsonl')):
    rows = [json.loads(l) for l in open(path)]
    avg_t = sum(r['time_sec'] for r in rows) / len(rows)
    name = path.split('/')[-1].replace('_recon_metrics.jsonl', '')
    print(f'{name:<42}  {avg_t:>14.1f}s  {len(rows):>7}')
# Out:
# Model                                        Avg sec/epoch   Epochs
# --------------------------------------------------------------------
# celeba_fourier                                       147.9s       30
# celeba_fourier_superres64to256                        61.5s       30
# celeba_relu                                          132.1s       30
# celeba_relu_superres64to256                           59.6s       30
# celeba_siren                                         177.5s       26
# celeba_siren_superres64to256                         167.0s       30
# cifar10_fourier                                       18.9s      120
# cifar10_relu                                          17.3s      120
# cifar10_siren                                         22.2s      120

# %%
import json, glob, matplotlib.pyplot as plt

datasets = ['cifar10', 'celeba']
metrics  = [('psnr', 'PSNR (dB)↑'), ('ssim', 'SSIM↑'), ('lpips', 'LPIPS↓')]
fig, axes = plt.subplots(len(datasets), len(metrics), figsize=(16, 9))

for row, ds in enumerate(datasets):
    for col, (metric, label) in enumerate(metrics):
        ax = axes[row][col]
        for path in sorted(glob.glob(f'./runs/{ds}_*_recon_metrics.jsonl')):
            if 'superres' in path:
                continue
            arch = path.split(f'{ds}_')[1].split('_recon')[0]
            rows = [json.loads(l) for l in open(path)]
            vals = [r[metric] for r in rows if metric in r]
            ax.plot(range(1, len(vals)+1), vals, label=arch)
        ax.set_title(f'{ds.upper()} — {label}')
        ax.set_xlabel('Epoch'); ax.legend(); ax.grid(True)

plt.tight_layout()
plt.savefig('./runs/all_training_curves.png', dpi=150)
plt.show()

# %%
import json, glob, matplotlib.pyplot as plt

fig, axes = plt.subplots(1, 3, figsize=(15, 4))
for path in sorted(glob.glob('./runs/*_superres*_recon_metrics.jsonl')):
    arch = path.split('celeba_')[1].split('_superres')[0]
    rows = [json.loads(l) for l in open(path)]
    for ax, metric, label in zip(axes, ['psnr', 'ssim', 'lpips'], ['PSNR (dB)↑', 'SSIM↑', 'LPIPS↓']):
        vals = [r[metric] for r in rows if metric in r]
        ax.plot(range(1, len(vals)+1), vals, label=arch)
        ax.set_xlabel('Epoch'); ax.set_ylabel(label); ax.legend(); ax.grid(True)
plt.suptitle('Super-Resolution (64px→256px) — Architecture Comparison')
plt.tight_layout()
plt.savefig('./runs/superres_curves.png', dpi=150)
plt.show()
